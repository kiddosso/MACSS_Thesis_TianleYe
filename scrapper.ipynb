# %% [markdown]
# <h3> Extracting DOIs <h3>

# %%
import requests
import time
import json

def fetch_dois(url, params, issn, max_retries=5):
    dois = []
    doi_issue_dict = {}
    retries = 0

    while True:
        try:
            response = requests.get(url, params=params, timeout=10)
            
            if response.status_code == 429:
                print("Rate limit exceeded. Waiting 10 seconds...")
                time.sleep(10)
                continue
            elif response.status_code != 200:
                print(f"Error: {response.status_code}")
                retries += 1
                if retries >= max_retries:
                    print("Max retries reached. Exiting...")
                    break
                time.sleep(5)
                continue
            
            data = response.json()
            
            # Assuming the API returns items in message.items
            # Adjust this based on the actual response structure
            items = data["message"]["items"] if "items" in data["message"] else data["message"]
            
            if not items:
                print("No more items found. Exiting...")
                break
            
            for item in items:
                doi = item["DOI"]
                dois.append(doi)  # Add DOI to list
                
                # Check if 'title' exists in the item
                if "title" in item:
                    if isinstance(item["title"], list) and len(item["title"]) > 0:
                        title = item["title"][0]
                    else:
                        title = str(item["title"])
                else:
                    title = "No title available"
                    
                doi_issue_dict[doi] = title
            
            print(f"Retrieved {len(dois)} DOIs so far...")
            
            if len(dois) % 1000 == 0:
                with open(f"dois_{issn}_partial.txt", "w") as f:
                    for doi in dois:
                        f.write(f"{doi}\n")
            
            # Check if there are more pages
            next_cursor = data["message"].get("next-cursor")
            if not next_cursor:
                print("No more pages found. Exiting...")
                break
            
            params["cursor"] = next_cursor
            time.sleep(1)
            retries = 0
        
        except requests.exceptions.Timeout:
            print("Request timed out. Retrying...")
            retries += 1
            if retries >= max_retries:
                print("Max retries reached. Exiting...")
                break
            time.sleep(5)
        except Exception as e:
            print(f"An error occurred: {e}")
            # Save what we have so far instead of losing everything
            if dois:
                with open(f"dois_{issn}_error_partial.txt", "w") as f:
                    for doi in dois:
                        f.write(f"{doi}\n")
                with open(f"doi_issues_{issn}_title_error_partial.json", "w") as f:
                    json.dump(doi_issue_dict, f, indent=2)
                print(f"Saved {len(dois)} DOIs collected before error.")
            break

    # Save DOIs to a text file
    with open(f"dois_{issn}.txt", "w") as f:
        for doi in dois:
            f.write(f"{doi}\n")

    # Save DOI-issue mapping as JSON
    with open(f"doi_issues_{issn}_title.json", "w") as f:
        json.dump(doi_issue_dict, f, indent=2)

    print(f"Retrieved {len(dois)} DOIs. Saved to dois_{issn}.txt and doi_issues_{issn}_title.json")

# %%
import requests
import time
import json
import random

def fetch_dois(url, params, issn, max_retries=5, initial_delay=1, max_delay=30):
    dois = []
    doi_issue_dict = {}
    retries = 0
    current_delay = initial_delay
    request_count = 0

    while True:
        try:
            # Add jitter to avoid predictable patterns that might trigger rate limiting
            actual_delay = current_delay * (0.8 + 0.4 * random.random())  # 80-120% of current delay
            
            # Every 10 requests, take a longer break to be extra cautious
            if request_count > 0 and request_count % 10 == 0:
                print(f"Taking a short break after {request_count} requests...")
                time.sleep(actual_delay * 2)
            
            request_count += 1
            response = requests.get(url, params=params, timeout=10)
            
            if response.status_code == 429:
                print(f"Rate limit exceeded. Waiting {current_delay * 2} seconds...")
                time.sleep(current_delay * 2)
                # Double the delay for next time, up to max_delay
                current_delay = min(current_delay * 2, max_delay)
                continue
            elif response.status_code != 200:
                print(f"Error: {response.status_code}")
                retries += 1
                if retries >= max_retries:
                    print("Max retries reached. Exiting...")
                    break
                time.sleep(current_delay)
                continue
            
            # Gradually reset delay on successful requests
            if current_delay > initial_delay:
                current_delay = max(current_delay * 0.8, initial_delay)
            
            data = response.json()
            
            # Assuming the API returns items in message.items
            # Adjust this based on the actual response structure
            items = data["message"]["items"] if "items" in data["message"] else data["message"]
            
            if not items:
                print("No more items found. Exiting...")
                break
            
            for item in items:
                doi = item["DOI"]
                dois.append(doi)  # Add DOI to list
                
                # Check if 'title' exists in the item
                if "title" in item:
                    if isinstance(item["title"], list) and len(item["title"]) > 0:
                        title = item["title"][0]
                    else:
                        title = str(item["title"])
                else:
                    title = "No title available"
                    
                doi_issue_dict[doi] = title
            
            print(f"Retrieved {len(dois)} DOIs so far...")
            
            if len(dois) % 1000 == 0:
                with open(f"dois_{issn}_partial.txt", "w") as f:
                    for doi in dois:
                        f.write(f"{doi}\n")
                # Also save partial JSON results
                with open(f"doi_issues_{issn}_title_partial.json", "w") as f:
                    json.dump(doi_issue_dict, f, indent=2)
            
            # Check if there are more pages
            next_cursor = data["message"].get("next-cursor")
            if not next_cursor:
                print("No more pages found. Exiting...")
                break
            
            params["cursor"] = next_cursor
            # Use dynamic delay between requests
            time.sleep(actual_delay)
            retries = 0
        
        except requests.exceptions.Timeout:
            print(f"Request timed out. Waiting {current_delay} seconds before retrying...")
            retries += 1
            if retries >= max_retries:
                print("Max retries reached. Exiting...")
                break
            time.sleep(current_delay)
            # Increase delay for next attempt
            current_delay = min(current_delay * 1.5, max_delay)
        except Exception as e:
            print(f"An error occurred: {e}")
            # Save what we have so far instead of losing everything
            if dois:
                with open(f"dois_{issn}_error_partial.txt", "w") as f:
                    for doi in dois:
                        f.write(f"{doi}\n")
                with open(f"doi_issues_{issn}_title_error_partial.json", "w") as f:
                    json.dump(doi_issue_dict, f, indent=2)
                print(f"Saved {len(dois)} DOIs collected before error.")
            break

    # Save DOIs to a text file
    with open(f"dois_{issn}.txt", "w") as f:
        for doi in dois:
            f.write(f"{doi}\n")

    # Save DOI-issue mapping as JSON
    with open(f"doi_issues_{issn}_title.json", "w") as f:
        json.dump(doi_issue_dict, f, indent=2)

    print(f"Retrieved {len(dois)} DOIs. Saved to dois_{issn}.txt and doi_issues_{issn}_title.json")

# %% [markdown]
# Fetch DOIs of American Sociological Review

# %%
issn = "0003-1224"
url = f"https://api.crossref.org/journals/{issn}/works"
params = {"cursor": "*", "rows": 1000}
fetch_dois(url, params, issn, max_retries=5)
# Out:
# Retrieved 1000 DOIs so far...
# Retrieved 2000 DOIs so far...
# Retrieved 3000 DOIs so far...
# Retrieved 4000 DOIs so far...
# Retrieved 5000 DOIs so far...
# Retrieved 6000 DOIs so far...
# Retrieved 7000 DOIs so far...
# Retrieved 8000 DOIs so far...
# Retrieved 9000 DOIs so far...
# Retrieved 10000 DOIs so far...
# Taking a short break after 10 requests...
# Retrieved 11000 DOIs so far...
# Retrieved 12000 DOIs so far...
# Retrieved 13000 DOIs so far...
# Retrieved 13177 DOIs so far...
# No more items found. Exiting...
# Retrieved 13177 DOIs. Saved to dois_0003-1224.txt and doi_issues_0003-1224_title.json

# %% [markdown]
# Fetch DOIs of American Journal of Sociology

# %%
issn = "0002-9602"
url = f"https://api.crossref.org/journals/{issn}/works"
params = {"cursor": "*", "rows": 1000}
fetch_dois(url, params, issn, max_retries=5)
# Out:
# Retrieved 1000 DOIs so far...
# Retrieved 2000 DOIs so far...
# Retrieved 3000 DOIs so far...
# Retrieved 4000 DOIs so far...
# Retrieved 5000 DOIs so far...
# Retrieved 6000 DOIs so far...
# Retrieved 7000 DOIs so far...
# Retrieved 8000 DOIs so far...
# Retrieved 9000 DOIs so far...
# Retrieved 10000 DOIs so far...
# Taking a short break after 10 requests...
# Retrieved 11000 DOIs so far...
# Retrieved 12000 DOIs so far...
# Retrieved 13000 DOIs so far...
# Retrieved 14000 DOIs so far...
# Retrieved 15000 DOIs so far...
# Retrieved 16000 DOIs so far...
# Retrieved 17000 DOIs so far...
# Retrieved 18000 DOIs so far...
# Retrieved 19000 DOIs so far...
# Retrieved 20000 DOIs so far...
# Taking a short break after 20 requests...
# Retrieved 21000 DOIs so far...
# Retrieved 22000 DOIs so far...
# Retrieved 23000 DOIs so far...
# Retrieved 24000 DOIs so far...
# Retrieved 25000 DOIs so far...
# Retrieved 26000 DOIs so far...
# Retrieved 27000 DOIs so far...
# Retrieved 27612 DOIs so far...
# No more items found. Exiting...
# Retrieved 27612 DOIs. Saved to dois_0002-9602.txt and doi_issues_0002-9602_title.json

# %% [markdown]
# Delete all irrelevant DOIs in AJS

# %%
import re

pattern = re.compile(r'10\.1086/ajs\.[^\s]+')

input_file = 'dois_0002-9602.txt'
output_file = 'dois_0002-9602_clean.txt'

with open(input_file, 'r', encoding='utf-8') as fin, \
    open(output_file, 'w', encoding='utf-8') as fout:
    
    for line in fin:
        cleaned_line = re.sub(pattern, '', line)
        if cleaned_line == '\n':
            continue
        
        fout.write(cleaned_line)

# %% [markdown]
# <h3> Download all ASR PDFs <h3>

# %%
def split_list(lst, n):
    k, m = divmod(len(lst), n)
    return [lst[i*k + min(i, m):(i+1)*k + min(i+1, m)] for i in range(n)]

def split_doc(issn, n):
    with open(f'dois_{issn}.txt', 'r') as f:
        dois = [line.strip() for line in f if line.strip()]
        print(f"Total DOIs: {len(dois)}")

    chunks = split_list(dois, n)
    lines = 0

    for i, chunk in enumerate(chunks, start=1):
        print(f"Processing chunk {i} with {len(chunk)} DOIs")
        lines += len(chunk)
        with open(f'dois_{issn}_batch_{i}.txt', 'w') as f_out:
            f_out.write('\n'.join(chunk) + '\n')

    if lines == len(dois):
        print("All DOIs processed and saved.")

# %%
split_doc('0003-1224', 6)
# Out:
# Total DOIs: 13168
# Processing chunk 1 with 2195 DOIs
# Processing chunk 2 with 2195 DOIs
# Processing chunk 3 with 2195 DOIs
# Processing chunk 4 with 2195 DOIs
# Processing chunk 5 with 2194 DOIs
# Processing chunk 6 with 2194 DOIs
# All DOIs processed and saved.

# %%
from oafuncs.oa_down.literature import download5doi

# %%
download5doi(store_path=r'asr_pdf', txt_file=r'asr/asr_dois.txt')

# %% [markdown]
# <h3> Download all AJS PDFs <h3>

# %% [markdown]
# Trial

# %%
import undetected_chromedriver as uc
import time
import os

download_dir = os.path.abspath("downloads")
os.makedirs(download_dir, exist_ok=True)

options = uc.ChromeOptions()
prefs = {
    "download.default_directory": download_dir,
    "plugins.always_open_pdf_externally": True
}
options.add_experimental_option("prefs", prefs)

driver = uc.Chrome(options=options)

driver.get("https://www.journals.uchicago.edu/action/ssostart")
print("Please log in manually in the opened browser window.")
time.sleep(60)
input("After logging in, press Enter to continue...")


download_url = "https://www.journals.uchicago.edu/doi/pdf/10.1086/733012?download=true"
driver.get(download_url)
time.sleep(10)

print("Download should be complete. Check the download folder:", download_dir)
driver.quit()
# Out:
# 2025-04-16 21:21:53,923 - INFO - patching driver executable /Users/tianleyee/Library/Application Support/undetected_chromedriver/undetected_chromedriver
# Please log in manually in the opened browser window.
# Download should be complete. Check the download folder: /Users/tianleyee/Desktop/downloads

# %% [markdown]
# Implement

# %%
import undetected_chromedriver as uc
import time
import os
import random

def login_and_download_papers(download_urls, download_dir="ajs_pdf", 
                              login_url="https://www.journals.uchicago.edu/action/ssostart"):
    
    download_dir = os.path.abspath(download_dir)
    os.makedirs(download_dir, exist_ok=True)
    
    options = uc.ChromeOptions()
    prefs = {
        "download.default_directory": download_dir,
        "plugins.always_open_pdf_externally": True
    }
    options.add_experimental_option("prefs", prefs)
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36")
    
    driver = uc.Chrome(options=options)
    
    driver.get(login_url)
    print("Please log in manually in the opened browser window.")
    time.sleep(60)
    input("After successfully logging in, press Enter to continue...")
    
    failed_downloads = []

    for url in download_urls:
        try:
            print(f"Downloading paper from: {url}")
            driver.get(url)
            time.sleep(2)
        except Exception as e:
            failed_downloads.append(url)
            print(f"Error downloading {url}: {e}")
            continue
    
    print("All downloads should be complete. Check the download folder:", download_dir)
    driver.quit()

# %%
with open('ajs/doi/dois_0002-9602.txt', 'r') as f:
    ajs_urls = [f"https://www.journals.uchicago.edu/doi/pdf/{doi}?download=true" for doi in f.read().splitlines()]

# %%
login_and_download_papers(ajs_urls[22000:])
# Out:
# Please log in manually in the opened browser window.
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230277?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228279?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210508?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210936?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213400?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210623?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225917?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/343179?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211402?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230433?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220389?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230896?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231245?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226148?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/668647?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230325?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229150?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/694419?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230961?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231135?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210533?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/677134?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215689?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/666981?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/526472?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/696952?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229686?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226886?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220467?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230075?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/700869?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223208?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222395?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211278?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219114?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227694?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231335?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210668?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225374?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229931?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222028?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218824?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218867?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218057?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222921?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228384?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230848?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228369?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/491764?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220905?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222578?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210764?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210199?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230054?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218389?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/597443?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216793?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216625?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/380892?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/592522?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224924?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217307?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213606?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228168?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220268?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223081?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210560?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217740?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227621?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213533?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227030?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228743?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227252?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215399?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213625?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216526?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225658?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227962?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216657?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231071?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227933?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215253?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/669658?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212313?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/655647?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217521?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211147?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/703729?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/214681?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210166?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221229?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226989?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230081?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/704153?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/651337?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217138?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231229?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230186?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227133?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213495?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212476?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/696212?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223150?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230732?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212505?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/318969?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224326?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222484?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223752?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222851?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/667767?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221663?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218763?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226494?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215627?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215476?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222773?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210423?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221334?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212742?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226560?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216639?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211514?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210010?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212854?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225267?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/677247?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228225?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/692904?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218526?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228611?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227266?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227863?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231349?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220876?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231164?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211589?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217423?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226124?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/719927?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225550?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/720064?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213492?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212624?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219458?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225161?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216313?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/499511?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/375199?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217872?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/708067?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226784?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213678?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/685442?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/722299?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/674571?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/718471?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228951?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211418?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230354?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227203?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225589?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/711015?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215533?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227416?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212073?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229187?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228061?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210172?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224187?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229603?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222551?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222095?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225984?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224427?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213081?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219558?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224920?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216197?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/686049?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215440?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/709605?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/708027?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/343194?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224927?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230982?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218285?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/605750?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226943?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213043?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215261?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/600312?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221461?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221979?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/316987?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217868?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227652?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/338524?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231137?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218166?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228774?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227381?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/655673?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229889?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/320320?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213063?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229772?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221665?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221708?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229733?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222393?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223421?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/522407?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211809?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211179?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/605748?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218565?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229585?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218351?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223341?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225046?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225379?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/499014?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224695?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216884?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216932?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220096?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215432?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210966?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219080?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226771?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/502998?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230093?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226587?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226760?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224198?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222920?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213871?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223785?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217827?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212513?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228765?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211404?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227186?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/704750?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227649?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227838?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/382007?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/693741?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222959?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221737?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227585?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218471?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220845?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216543?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225873?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223088?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/214615?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219069?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211290?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219609?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227932?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219754?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215555?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220266?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213317?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221432?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/378458?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228747?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225113?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215602?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230905?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216540?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226541?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227724?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/214487?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213734?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/663670?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231304?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212343?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/687200?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228477?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/683616?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/506224?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224113?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220097?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217791?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/711872?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/376282?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230979?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/678971?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225780?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229037?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228379?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220893?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217274?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212252?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/599148?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218141?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/680589?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227085?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223091?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226878?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/649253?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222505?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215674?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224146?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228970?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216342?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210385?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217139?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227893?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216339?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226256?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/600375?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229554?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228520?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220364?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217478?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215537?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227899?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224048?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215715?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213114?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/715531?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212892?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229131?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227478?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218162?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219224?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210902?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218891?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212691?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212666?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213206?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210301?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/320302?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/649244?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224396?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226833?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224294?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210838?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/649577?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/426554?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224978?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223264?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225030?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218118?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228247?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221263?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227298?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220165?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223863?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219101?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224109?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211243?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/500767?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216312?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211732?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230449?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220400?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218845?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211162?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225110?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213710?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216585?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/656428?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221906?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211562?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230288?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225253?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/376328?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221776?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/303142?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222320?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/699354?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/708657?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212046?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222632?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224303?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230680?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211369?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224309?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215205?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/214977?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217864?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212316?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213733?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212554?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210740?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/214683?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213607?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220174?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211979?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223639?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210243?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221084?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215266?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223899?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226664?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224025?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222072?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210692?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215988?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218533?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229039?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230616?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/214216?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/677135?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/717204?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227368?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220830?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215492?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229189?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213716?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216175?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223303?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227990?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216727?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218620?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211096?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212821?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216319?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/700956?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/214936?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215078?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/214695?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/518054?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228035?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231383?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229928?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210348?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/656225?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224930?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222382?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215852?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229123?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210861?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221009?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229208?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/665559?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/677052?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221652?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227858?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225832?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/431617?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215836?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223204?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/680513?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221476?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/605743?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/510031?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222336?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/214296?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219949?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221135?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230157?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/683635?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216623?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211946?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210998?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230723?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220546?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228024?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211171?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227535?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223376?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/513540?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219527?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225687?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224613?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227599?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211625?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220084?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/692720?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222163?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/213179?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215888?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224203?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/686045?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223185?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215257?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229399?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229184?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229892?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219465?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226244?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212966?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227880?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227604?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/344882?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/680463?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216588?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224128?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216026?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230039?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/670986?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216141?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228811?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212260?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215404?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210130?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211057?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215349?download=true
# ...
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/379919?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219426?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/214447?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225195?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228244?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217712?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223990?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228950?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219185?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225361?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220270?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220368?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228119?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222105?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226742?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226702?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227555?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/378340?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222127?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/214336?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220398?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225636?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223308?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225199?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227353?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228046?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227490?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220818?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221204?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223306?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/682026?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224263?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217257?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/705561?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226935?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228947?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216177?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215664?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/426412?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225852?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226223?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224723?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225554?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/649050?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221704?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/703682?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/683819?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/518923?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/668646?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/655752?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/705514?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224893?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223162?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/216223?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/709779?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/695766?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/344811?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224949?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230450?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226738?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218489?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231291?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231293?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217919?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227091?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220939?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226354?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/223309?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220717?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226972?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224932?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/381913?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218522?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225552?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227419?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224800?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229424?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210642?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/320818?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224170?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211871?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222655?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227914?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/217773?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226508?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/590991?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220533?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210858?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228314?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/225409?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229665?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231416?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/343154?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/655637?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212969?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222386?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/222549?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231295?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/707985?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224664?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220638?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224087?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221017?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221955?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231211?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220890?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230371?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224032?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229613?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/220640?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227318?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229326?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/421541?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/666384?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/718179?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/512710?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/592208?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224976?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230642?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/224906?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210001?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/221694?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226640?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227636?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219685?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/215282?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/303111?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/377517?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/728786?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/683144?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/689890?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/689814?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/688650?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/688892?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/686941?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/661985?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/525506?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/595946?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/651940?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/521839?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/657114?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/655754?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/651448?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/511799?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/444445?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/374405?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/374404?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/508792?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226510?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/230995?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231213?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229274?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226937?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226109?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210359?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/210316?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/228084?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/226708?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/212433?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/211783?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/218177?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/229654?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/214592?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/231399?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/227709?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/219652?download=true
# Downloading paper from: https://www.journals.uchicago.edu/doi/pdf/10.1086/693678?download=true
# All downloads should be complete. Check the download folder: /Users/tianleyee/Desktop/ajs_pdf

# %% [markdown]
# <h3> Get ASR paper dois

# %%
import json

with open('doi_issues_0003-1224_title.json', 'r') as f:
    asr_doi_titles = json.load(f)

# %%
with open("asr/doi_issues_0003-1224.json", "r") as f:
    asr_doi_issues = json.load(f)

# %%
with open('doi_issues_0003-1224_title.json', 'r') as f:
    asr_doi_titles = json.load(f)

# %%
asr_dois_2010s = []

for doi, issue in asr_doi_issues.items():
    try:
        number = int(issue.split('(')[0])
        year = number + 1935
        if 2010 <= year < 2020:
            asr_dois_2010s.append(doi)
    except ValueError:
        print(f"Skipping DOI {doi} due to parsing error with issue: {issue}")
# Out:
# Skipping DOI 10.1177/00031224241298008 due to parsing error with issue: N/A
# Skipping DOI 10.1177/00031224241303459 due to parsing error with issue: N/A
# Skipping DOI 10.1177/00031224241286480 due to parsing error with issue: N/A
# Skipping DOI 10.1177/00031224241305357 due to parsing error with issue: N/A

# %%
asr_dois_2010_with_titles = {doi: title for doi, title in asr_doi_titles.items() if doi in asr_dois_2010s}

# %%
len(asr_dois_2010_with_titles)
# Out:
# 484

# %%
asr_paper_2020_dois = []
asr_paper_2020_dois_with_titles = {}
excluded_patterns = [
    "Acknowledgment of Referees",
    "ASR 2010 to 2012",
    "Comments",
    "Correction",
    "Corrigendum",
    "Editorial Transition",
    "Editors' Comment",
    "Further Data",
    "Errata",
    "Erratum",
    "Index",
    "Meeting the Challenges of a 21st-Century Flagship Journal"
]


for doi, title in asr_dois_2010_with_titles.items():
    should_exclude = False
    for pattern in excluded_patterns:
        if pattern in title:
            should_exclude = True
            break
    
    if not should_exclude:
        asr_paper_2020_dois.append(doi)
        asr_paper_2020_dois_with_titles[doi] = title

# %%
for doi in asr_paper_2020_dois:
    print(doi)
# Out:
# 10.1177/0003122419832497
# 10.1177/0003122411420814
# 10.1177/0003122413480362
# 10.1177/0003122411407736
# 10.1177/0003122411420815
# 10.1177/0003122412448050
# 10.1177/0003122411407748
# 10.1177/0003122412470829
# 10.1177/0003122413505198
# 10.1177/0003122413505588
# 10.1177/0003122419844992
# 10.1177/0003122414528936
# 10.1177/0003122415589170
# 10.1177/0003122418811112
# 10.1177/0003122412469204
# 10.1177/0003122419831228
# 10.1177/0003122411428221
# 10.1177/0003122410396195
# 10.1177/0003122418759544
# 10.1177/0003122416670655
# 10.1177/0003122415596999
# 10.1177/0003122418806284
# 10.1177/0003122414553657
# 10.1177/0003122410382639
# 10.1177/0003122418784909
# 10.1177/0003122417712729
# 10.1177/0003122411420816
# 10.1177/0003122410363563
# 10.1177/0003122410363564
# 10.1177/0003122419846849
# 10.1177/0003122413476034
# 10.1177/0003122413512316
# 10.1177/0003122413494759
# 10.1177/0003122414531596
# 10.1177/0003122416683394
# 10.1177/0003122415613078
# 10.1177/0003122418792836
# 10.1177/0003122417703087
# 10.1177/0003122419877135
# 10.1177/0003122417718165
# 10.1177/0003122410374822
# 10.1177/0003122415581333
# 10.1177/0003122419846628
# 10.1177/0003122418796807
# 10.1177/0003122410372229
# 10.1177/0003122414547756
# 10.1177/0003122417737951
# 10.1177/0003122413484150
# 10.1177/0003122415601157
# 10.1177/0003122419884917
# 10.1177/0003122412465331
# 10.1177/0003122416663917
# 10.1177/0003122415618991
# 10.1177/0003122419885094
# 10.1177/0003122416685812
# 10.1177/0003122413491964
# 10.1177/0003122412465743
# 10.1177/0003122415601618
# 10.1177/0003122410386686
# 10.1177/0003122415574328
# 10.1177/0003122415577989
# 10.1177/0003122417734353
# 10.1177/0003122416663464
# 10.1177/0003122416653603
# 10.1177/0003122416644414
# 10.1177/0003122414544734
# 10.1177/0003122418797576
# 10.1177/0003122411427673
# 10.1177/0003122415573049
# 10.1177/0003122419826020
# 10.1177/0003122417691503
# 10.1177/0003122410395370
# 10.1177/0003122412458785
# 10.1177/0003122414555886
# 10.1177/0003122417705874
# 10.1177/0003122414536391
# 10.1177/0003122418761857
# 10.1177/0003122414534065
# 10.1177/0003122416641372
# 10.1177/0003122415571582
# 10.1177/0003122419846111
# 10.1177/0003122417720466
# 10.1177/0003122418781774
# 10.1177/0003122410396197
# 10.1177/0003122412458508
# 10.1177/0003122410374085
# 10.1177/0003122418772061
# 10.1177/0003122417747290
# 10.1177/0003122419858731
# 10.1177/0003122419833386
# 10.1177/0003122415622391
# 10.1177/0003122417728240
# 10.1177/0003122419837567
# 10.1177/0003122416671742
# 10.1177/0003122412440802
# 10.1177/0003122412464041
# 10.1177/0003122410395369
# 10.1177/0003122413514584
# 10.1177/0003122414524574
# 10.1177/0003122418785368
# 10.1177/0003122417747289
# 10.1177/0003122410386689
# 10.1177/0003122417739294
# 10.1177/0003122414524207
# 10.1177/0003122413480363
# 10.1177/0003122411414822
# 10.1177/0003122411407737
# 10.1177/0003122413497012
# 10.1177/0003122418759651
# 10.1177/0003122412452874
# 10.1177/0003122419871959
# 10.1177/0003122419859574
# 10.1177/0003122412440093
# 10.1177/0003122416629756
# 10.1177/0003122413519445
# 10.1177/0003122414549552
# 10.1177/0003122417710462
# 10.1177/0003122414551552
# 10.1177/0003122412463574
# 10.1177/0003122414543557
# 10.1177/0003122414554947
# 10.1177/0003122417690325
# 10.1177/0003122416663683
# 10.1177/0003122415596416
# 10.1177/0003122416630982
# 10.1177/0003122418791174
# 10.1177/0003122414564182
# 10.1177/0003122418808212
# 10.1177/0003122418820702
# 10.1177/0003122417693616
# 10.1177/0003122410365305
# 10.1177/0003122414543659
# 10.1177/0003122411420813
# 10.1177/0003122418794635
# 10.1177/0003122414556308
# 10.1177/0003122413515997
# 10.1177/0003122411411901
# 10.1177/0003122411427177
# 10.1177/0003122411432701
# 10.1177/0003122414548194
# 10.1177/0003122417752355
# 10.1177/0003122412457875
# 10.1177/0003122415612469
# 10.1177/0003122415583487
# 10.1177/0003122417690497
# 10.1177/0003122411425170
# 10.1177/0003122416633140
# 10.1177/0003122412445802
# 10.1177/0003122409359165
# 10.1177/0003122412441791
# 10.1177/0003122412463213
# 10.1177/0003122417753112
# 10.1177/0003122414529771
# 10.1177/0003122411427672
# 10.1177/0003122411401249
# 10.1177/0003122417714422
# 10.1177/0003122413498255
# 10.1177/0003122418781791
# 10.1177/0003122411434610
# 10.1177/0003122415598534
# 10.1177/0003122415574329
# 10.1177/0003122416658294
# 10.1177/0003122417706463
# 10.1177/0003122412438225
# 10.1177/0003122418822335
# 10.1177/0003122411420817
# 10.1177/0003122413500274
# 10.1177/0003122415576516
# 10.1177/0003122411427580
# 10.1177/0003122415587313
# 10.1177/0003122410380868
# 10.1177/0003122410388491
# 10.1177/0003122412468882
# 10.1177/0003122412458509
# 10.1177/0003122411401252
# 10.1177/0003122410374083
# 10.1177/0003122410372216
# 10.1177/0003122411401250
# 10.1177/0003122416651312
# 10.1177/0003122417735742
# 10.1177/0003122413493285
# 10.1177/0003122417728662
# 10.1177/0003122411414827
# 10.1177/0003122414521810
# 10.1177/0003122418762291
# 10.1177/0003122418794503
# 10.1177/0003122415606101
# 10.1177/0003122409357045
# 10.1177/0003122417725175
# 10.1177/0003122410363566
# 10.1177/0003122415597019
# 10.1177/0003122418785371
# 10.1177/0003122416675175
# 10.1177/0003122414562600
# 10.1177/0003122416683393
# 10.1177/0003122411399390
# 10.1177/0003122415588558
# 10.1177/0003122413496252
# 10.1177/0003122414546931
# 10.1177/0003122411433762
# 10.1177/0003122416686521
# 10.1177/0003122414530398
# 10.1177/0003122414536392
# 10.1177/0003122414561117
# 10.1177/0003122414555885
# 10.1177/0003122410379581
# 10.1177/0003122413500273
# 10.1177/0003122414559043
# 10.1177/0003122416681031
# 10.1177/0003122413509627
# 10.1177/0003122417733673
# 10.1177/0003122414555399
# 10.1177/0003122419859007
# 10.1177/0003122413487197
# 10.1177/0003122417695791
# 10.1177/0003122413518638
# 10.1177/0003122419879101
# 10.1177/0003122418795856
# 10.1177/0003122418759679
# 10.1177/0003122419886550
# 10.1177/0003122413477419
# 10.1177/0003122410388488
# 10.1177/0003122416632212
# 10.1177/0003122412447793
# 10.1177/0003122416632787
# 10.1177/0003122416674025
# 10.1177/0003122416639625
# 10.1177/0003122414520960
# 10.1177/0003122414545986
# 10.1177/0003122415621910
# 10.1177/0003122417691952
# 10.1177/0003122419858729
# 10.1177/0003122414524573
# 10.1177/0003122417709294
# 10.1177/0003122416629611
# 10.1177/0003122415572463
# 10.1177/0003122419859519
# 10.1177/0003122417717901
# 10.1177/0003122416663929
# 10.1177/0003122409359166
# 10.1177/0003122410396196
# 10.1177/0003122418759546
# 10.1177/0003122414564998
# 10.1177/0003122413516342
# 10.1177/0003122416671873
# 10.1177/0003122416668154
# 10.1177/0003122414541960
# 10.1177/0003122412473107
# 10.1177/0003122415613414
# 10.1177/0003122411414815
# 10.1177/0003122414558919
# 10.1177/0003122419871957
# 10.1177/0003122415590627
# 10.1177/0003122412451019
# 10.1177/0003122418806282
# 10.1177/0003122416653602
# 10.1177/0003122413484151
# 10.1177/0003122418780366
# 10.1177/0003122416643758
# 10.1177/0003122418816109
# 10.1177/0003122412465282
# 10.1177/0003122412444720
# 10.1177/0003122413484923
# 10.1177/0003122416673029
# 10.1177/0003122413492762
# 10.1177/0003122411433763
# 10.1177/0003122413506440
# 10.1177/0003122413487904
# 10.1177/0003122412472048
# 10.1177/0003122415621900
# 10.1177/0003122418818198
# 10.1177/0003122414529585
# 10.1177/0003122418811264
# 10.1177/0003122416653112
# 10.1177/0003122411428153
# 10.1177/0003122414524575
# 10.1177/0003122414539682
# 10.1177/0003122411414820
# 10.1177/0003122415581334
# 10.1177/0003122414564008
# 10.1177/0003122416655340
# 10.1177/0003122411400054
# 10.1177/0003122417736289
# 10.1177/0003122413501859
# 10.1177/0003122413481351
# 10.1177/0003122416641371
# 10.1177/0003122417716611
# 10.1177/0003122416638652
# 10.1177/0003122417694456
# 10.1177/0003122411409705
# 10.1177/0003122412460649
# 10.1177/0003122409359168
# 10.1177/0003122416631989
# 10.1177/0003122412471669
# 10.1177/0003122413489877
# 10.1177/0003122419857797
# 10.1177/0003122412458672
# 10.1177/0003122412464040
# 10.1177/0003122419875638
# 10.1177/0003122417705656
# 10.1177/0003122413505589
# 10.1177/0003122412448648
# 10.1177/0003122414531435
# 10.1177/0003122418782476
# 10.1177/0003122419859533
# 10.1177/0003122412450573
# 10.1177/0003122419836081
# 10.1177/0003122410363293
# 10.1177/0003122415609730
# 10.1177/0003122412444721
# 10.1177/0003122411411276
# 10.1177/0003122417702367
# 10.1177/0003122417710642
# 10.1177/0003122415623286
# 10.1177/0003122410379582
# 10.1177/0003122412472340
# 10.1177/0003122414531776
# 10.1177/0003122416635667
# 10.1177/0003122413489130
# 10.1177/0003122416663494
# 10.1177/0003122417749632
# 10.1177/0003122416671743
# 10.1177/0003122410381593
# 10.1177/0003122412441354
# 10.1177/0003122414568788
# 10.1177/0003122417751442
# 10.1177/0003122417728719
# 10.1177/0003122416688667
# 10.1177/0003122410374086
# 10.1177/0003122416662958
# 10.1177/0003122411435905
# 10.1177/0003122416642430
# 10.1177/0003122411435477
# 10.1177/0003122412449014
# 10.1177/0003122417727095
# 10.1177/0003122411414825
# 10.1177/0003122413501071
# 10.1177/0003122414565391
# 10.1177/0003122411399389
# 10.1177/0003122417725865
# 10.1177/0003122418823184
# 10.1177/0003122411414817
# 10.1177/0003122413518553
# 10.1177/0003122418803376
# 10.1177/0003122418772857
# 10.1177/0003122410388493
# 10.1177/0003122411430496
# 10.1177/0003122410368927
# 10.1177/0003122414529586
# 10.1177/0003122416650149
# 10.1177/0003122411398443
# 10.1177/0003122417728241
# 10.1177/0003122416673598
# 10.1177/0003122415579989
# 10.1177/0003122418767438
# 10.1177/0003122415615903
# 10.1177/0003122412473108
# 10.1177/0003122410388501
# 10.1177/0003122413513022
# 10.1177/0003122413476712
# 10.1177/0003122419872671
# 10.1177/0003122419833601
# 10.1177/0003122416684777
# 10.1177/0003122415583649
# 10.1177/0003122410374084
# 10.1177/0003122412463018
# 10.1177/0003122415591268
# 10.1177/0003122415598764
# 10.1177/0003122418821339
# 10.1177/0003122416645594
# 10.1177/0003122416639609
# 10.1177/0003122417701115
# 10.1177/0003122411436234
# 10.1177/0003122410363567
# 10.1177/0003122414538966
# 10.1177/0003122410368929
# 10.1177/0003122411430940
# 10.1177/0003122415609051
# 10.1177/0003122412443365
# 10.1177/0003122414554081
# 10.1177/0003122410396194
# 10.1177/0003122418772567
# 10.1177/0003122418773353
# 10.1177/0003122414534438
# 10.1177/0003122414553656
# 10.1177/0003122414555398
# 10.1177/0003122414537644
# 10.1177/0003122412457156
# 10.1177/0003122410386688
# 10.1177/0003122410382640
# 10.1177/0003122419848723
# 10.1177/0003122415619617
# 10.1177/0003122417713188
# 10.1177/0003122411409704
# 10.1177/0003122415591800
# 10.1177/0003122417695841
# 10.1177/0003122419872504
# 10.1177/0003122409357064
# 10.1177/0003122414534437
# 10.1177/0003122410365308
# 10.1177/0003122414565814
# 10.1177/0003122414544733
# 10.1177/0003122414568649
# 10.1177/0003122415607230
# 10.1177/0003122413514750
# 10.1177/0003122416648189
# 10.1177/0003122412453921
# 10.1177/0003122416642419
# 10.1177/0003122419883255
# 10.1177/0003122411416934
# 10.1177/0003122416656360
# 10.1177/0003122415592129
# 10.1177/0003122414540653
# 10.1177/0003122412448796
# 10.1177/0003122414535774
# 10.1177/0003122409357044
# 10.1177/0003122413478816
# 10.1177/0003122413508285
# 10.1177/0003122416650963
# 10.1177/0003122415599155
# 10.1177/0003122419856347
# 10.1177/0003122410378232
# 10.1177/0003122418809374
# 10.1177/0003122412472680
# 10.1177/0003122415621263
# 10.1177/0003122413509813
# 10.1177/0003122418816958
# 10.1177/0003122418772034
# 10.1177/0003122410372226
# 10.1177/0003122419884497
# 10.1177/0003122418773775
# 10.1177/0003122413491963
# 10.1177/0003122410372230
# 10.1177/0003122418808005
# 10.1177/0003122413486800
# 10.1177/0003122411400056
# 10.1177/0003122409359164
# 10.1177/0003122417706391
# 10.1177/0003122415581335
# 10.1177/0003122410365307
# 10.1177/0003122412451728
# 10.1177/0003122413500784
# 10.1177/0003122412442883
# 10.1177/0003122409357047
# 10.1177/0003122411409698
# 10.1177/0003122417711699
# 10.1177/0003122413482919
# 10.1177/0003122418762441
# 10.1177/0003122414554001
# 10.1177/0003122416659248
# 10.1177/0003122414523616
# 10.1177/0003122419874843
# 10.1177/0003122419847165

# %% [markdown]
# <h3> Get AJS paper dois <h3>

# %%
import json

with open('doi_issues_0002-9602_title.json', 'r') as f:
    ajs_doi_titles = json.load(f)

# %%
ajs_paper_dois = []
ajs_paper_dois_with_titles = {}
excluded_patterns = [
    "<i>",  # Italics tags
    "A Letter from",
    "Abstracts of",
    "Acknowledgments",
    "Annual Meeting",
    "Appendix",
    "Announcement",
    "Author Index",
    "Back Matter",
    "Bibliography",
    'Bibliographical Note',
    "Book Notes",
    "Book Review",
    "BOOK REVIEWERS",
    "Book Received",
    "Books Received",
    "Comment on",
    "Contents of Volume",
    "Contributors",
    "Current Books",
    "Current Research Projects",
    "Editor's",
    "Editor’s",
    "Editorial",
    "Erratum",
    "Errata",
    "Foreword",
    "Front Matter",
    "In Memoriam",
    "Index to Volume",
    "Introduction to Symposium",
    "Letter to the Editor",
    "Letters to the Editor",
    "Masthead",
    "News and Notes",
    "News from Abroad",
    "No title available",
    "Notes and Abstracts",
    "Obituary",
    "Preface",
    "Recent Literature",
    "Rejoinder",
    "Reply",
    "Replies",
    "Municipal Review",
    "Review Essay",
    "Subject Index",
    "Students' Dissertations in Sociology",
    "the President of the American Sociological Society",
    "The Family",
    "Volume Information"
]

absolute_excluded_patterns = [
    "Communication", #?
    "Comment", #?
]

for doi, title in ajs_doi_titles.items():
    should_exclude = False
    for pattern in excluded_patterns:
        if pattern in title:
            should_exclude = True
            break
    for pattern in absolute_excluded_patterns:
        if pattern == title:
            should_exclude = True
            break
    
    if not should_exclude:
        ajs_paper_dois.append(doi)
        ajs_paper_dois_with_titles[doi] = title

# %%
len(ajs_paper_dois_with_titles)
# Out:
# 5714

# %%
[title for title in ajs_paper_dois_with_titles.values()]
# Out:
# ['Community Organization',
#  'The Basis of Sociality',
#  'When Truth Trumps Facts: Studies on Partisan Moral Flexibility in American Politics',
#  'The Literary Interests of Chicago. I and II',
#  'Education',
#  'The First German Municipal Exposition. (Dresden, 1903.) III',
#  'Attitudinal Multivalence in Relation to Culture and Personality',
#  'A Movement to Preserve Social Science Source Materials',
#  'The Relation of Sex to Primitive Social Control',
#  'The Race-Preservation Dogma',
#  'How Much Post-War Migration?',
#  'The Russian Experiment',
#  'The Structure of Intergenerational Exchanges in American Families',
#  'Escape from the GDR, 1961–1989: Hybrid Exit Repertoires in a Disintegrating Leninist Regime',
#  'Talking City Trouble: Interactional Vandalism, Social Inequality, and the “Urban Interaction Problem”',
#  'Community Change and Patterns of Delinquency',
#  'Introduction to Sociology. X',
#  'Population of the United States, 1925 to 1975',
#  'The Development of Rural Sociology',
#  'The Sad Estate of Scientific Publication',
#  'National Preparedness--American',
#  'Ability to Alter Skin Color: Some Implications for American Society',
#  'Philadelphia Street-Railway Franchises.',
#  'An Experimental Study of the Influence of Suggestion on the Discrimination and the Valuation of People',
#  'Propinquity of Residence Before Marriage',
#  'The Conditions and Prospects for a World Without War',
#  'A Supplement to the Case Record',
#  'The Evolution of the American Community',
#  'Social Role and Personal Security in Mormon Polygamy',
#  'Were Comte and Spencer Wholly Wrong?',
#  'The Transition of Civilizations in Primitive Society',
#  'Orientation of College Students Toward International Relations',
#  'The Era of Sociology',
#  'The Reformation of Juvenile Offenders in Illinois',
#  'Two Representative Contributions of Sociology to Political Theory: The Doctrines of William Graham Sumner and Lester Frank Ward',
#  'Sigmund Freud and Psychiatry a Partial Appraisal',
#  'Which Norms of Justice? A Commentary on Hamilton and Rytina',
#  'Comments on the Sociology of Georges Gurvitch',
#  'Concerning Certain Wise Limits to Charity Organization Society Work',
#  'A Neglected Utopian: Cyrano de Bergerac, 1619-55',
#  "Industrial Insurance. V. The Employers' Liability Law",
#  'The Epigenesis of Political Communities at the International Level',
#  'Conflict and Control Functions of Humor',
#  'Public Opinion and Public Ignorance: The Fine Line Between Attitudes and Nonattitudes',
#  'Multiple Victimization in American Cities: A Statistical Analysis of Rare Events',
#  'Status and Competence of Jurors',
#  'Social Control. XIV. Education',
#  'Education for Democratic Leadership',
#  'Observation and Generalization in Cultural Anthropology',
#  'Making Un-Americans',
#  'The Sourashtra Community in Madura, South India',
#  'The Postwar Population of the Soviet Union',
#  "German Workingmen's Insurance and Foreign Countries",
#  'Business Men and Social Theorists',
#  'The Transition to an Objective Standard of Social Control',
#  'Maurice Halbwachs, 1877-1945',
#  'Inner Personality, Image, and Social Role',
#  'The Evolution of Conscience as a Phase of Sociology',
#  'Primary and Secondary Aspects of Interstate Migrations',
#  'A Sociolinguistic Census of a Bilingual Neighborhood',
#  'Response to Hannan and Tuma',
#  'Changes in Income Distribution and Social Stratification: A Note',
#  'The Politics of Resentment in the Post–Civil Rights Era: Minority Threat, Homicide, and Ideological Voting in Congress',
#  "Democracy Unlimited: Kurt Lewin's Field Theory",
#  'Roles and Innovations in Medicine',
#  'Homicide and Social Contact in Denmark',
#  'Gans on Granovetter\'s "Strength of Weak Ties"',
#  "Men's and Women's Beliefs, Ideals, and Self-Concepts",
#  'Societal Complexity and Familial Complexity: Evidence for the Curvilinear Hypothesis',
#  'Abolition, the Extension of Slavery, and the Position of Free Blacks: A Study of Split Labor Markets in the United States, 1830-1863',
#  'Cross-National Evidence of the Effects of Foreign Investment and Aid on Economic Growth and Inequality: A Survey of Findings and a Reanalysis',
#  'Client Control and Medical Practice',
#  "What's Class Got to Do with It? A Further Examination of Power-Control Theory",
#  'Social Conflict and Minority Aspirations in Indonesia',
#  'Distance in Sociology',
#  "Characteristics of Successful American Protest Groups: Another Look at Gamson's Strategy of Social Protest",
#  '“737-Cabriolet”: The Limits of Knowledge and the Sociology of Inevitable Failure',
#  'Conservatism and Sociology',
#  'The Analysis of Systems of Qualitative Variables When Some of the Variables Are Unobservable. Part I-A Modified Latent Structure Approach',
#  'A Note on the Implications of Psychiatry, the Study of Interpersonal Relations, for Investigations in the Social Sciences',
#  'The Control of Managerial Discretion: Evidence from Unionization’s Impact on Employment Segregation',
#  'The Market Transition Debate: Toward a Synthesis?',
#  'A Psychological Theory of Revolutions',
#  'Higher Degrees in Sociology Conferred in 1949',
#  'The Emergent Organization of Plea Bargaining',
#  'On the Origin and Use of the Word "Sociology," and on the Relation of Sociological to Other Studies and to Practical Problems',
#  'Is an Honest and Sane Newspaper Press Possible?',
#  'Revolution or Incursion? Academic Sociologists and Gender in the 21st Century',
#  'Rationalizing the Irrational: Karl Mannheim and the Besetting Sin of German Intellectuals',
#  "The Boys' Club and Juvenile Delinquency",
#  'Queue Culture: The Waiting Line as a Social System',
#  'Local Party Systems: Theoretical Considerations and a Case Analysis',
#  'The Impact of Fictional Television Suicide Stories on U.S. Fatalities: A Replication',
#  'The Cocktail Lounge: A Study of Heterosexual Relations in a Public Organization',
#  'The Latent Structure of Job Characteristics of Men and Women',
#  'Education and the Cultural Crisis',
#  'Analyzing Recent Trends in Prejudice Toward Blacks: Insights from Latent Class Models',
#  'A Theory of Location for Cities',
#  'Happiness and Success: Genes, Families, and the Psychological Effects of Socioeconomic Position and Social Support',
#  'Clocking Out: Temporal Patterning of Retirement',
#  'Toward a Political Model of Incarceration: A Time-Series Examination of Multiple Explanations for Prison Admission Rates',
#  'Social Class and College Graduation: Some Misconceptions Corrected',
#  'Social Organization',
#  "A Critical Note on Goldenweiser's Categories",
#  'The American Pattern of Military Government in Micronesia',
#  'Organizational Goals and the Behavior of Informal Leaders',
#  'A Liberal Theory of Prestige',
#  'What Makes a Decision Fair? Relative Earnings, Gender, and Justifications for Couples’ Decision-Making',
#  'Conservatism, Institutionalism, and the Social Control of Intergroup Conflict',
#  'The Tradition of Opportunity and the Aspirations of Automobile Workers',
#  'Attitudes and Behavior',
#  'Indianapolis and Beyond: A Structural Model of Occupational Mobility Across Generations',
#  'The Professional Employee: A Study of Conflict in Nursing Roles',
#  'An Intensive Sociology: A Project',
#  'The Value of the Study of Colonies for Sociology',
#  'Organizational Invention and Elite Transformation: The Birth of Partnership Systems in Renaissance Florence',
#  'Selection by Certification: A Neglected Variable in Stratification Research',
#  'Sociology Before Comte: A Summary of Doctrines and an Introduction to the Literature',
#  'How to Become a Dominant French Philosopher: The Case of Jacques Derrida',
#  'The Lombrosian Myth in Criminology',
#  'The Social Function of Religion',
#  'A Redefinition of Social Phenomena: Giving a Basis for Comparative Sociology',
#  'City Directories as Sources of Migration Data',
#  'The Demography of Social Mobility: Black-White Differences in the Process of Educational Reproduction',
#  'Emergent Ghettos: Black Neighborhoods in New York and Chicago, 1880–1940',
#  'Class Identification in the United States',
#  'Toward an Integrated Theory of White-Collar Crime',
#  'Social Control',
#  "Encountering the Male Establishment: Sex-Status Limits on Women's Careers in the Professions",
#  'Pictures at an Exhibition: Conflicting Pressures in Museums and the Display of Art',
#  'The Emperor’s Dilemma: A Computational Model of Self‐Enforcing Norms',
#  'Narrating Social Structure: Stories of Resistance to Legal Authority',
#  'News as a Form of Knowledge: A Chapter in the Sociology of Knowledge',
#  'The Party of Lincoln and the Politics of State Fair Employment Practices Legislation in the North, 1945–1964',
#  'Why Do Liberals Drink Lattes?',
#  'Who Should Get What? Fairness Judgments of the Distribution of Earnings',
#  'Reputational Entrepreneurs and the Memory of Incompetence: Melting Supporters, Partisan Warriors, and Images of President Harding',
#  'Talcott Parsons and the Theory of Action. I. The Structure of the Kantian Core',
#  '“We’re Still Dying Quicker Than We Can Effect Change”: #BlackLivesMatter and the Limits of 21st-Century Policing Reform',
#  'The Protestant Ethic Revisited: Disciplinary Revolution and State Formation in Holland and Prussia',
#  'The Emergence of Exchange Structures: An Experimental Study of Uncertainty, Commitment, and Trust',
#  'I Will Follow Him: Family Ties, Gender-Role Beliefs, and Reluctance to Relocate for a Better Job',
#  '“Don’t put my name on it”: Social Capital Activation and Job‐Finding Assistance among the Black Urban Poor',
#  'Making Men Modern: On the Causes and Consequences of Individual Change in Six Developing Countries',
#  'The Cost of Color: Skin Color, Discrimination, and Health among African-Americans',
#  'How Many Latent Classes of Delinquent/ Criminal Careers? Results from Mixed Poisson Regression Analyses',
#  'Work in Progress Toward a New Paradigm for the Sociological Study of Religion in the United States',
#  'Ambiguity and Engagement',
#  'On the Concept of Face',
#  'Institutional Emergence in an Era of Globalization: The Rise of Transnational Private Regulation of Labor and Environmental Conditions',
#  'Networks as the Pipes and Prisms of the Market',
#  'When Does Gender Trump Money? Bargaining and Time in Household Work',
#  'The Context of Discrimination: Workplace Conditions, Institutional Environments, and Sex and Race Discrimination Charges',
#  'The Diffusion of Collective Violence: Infectiousness, Susceptibility, and Mass Media Networks',
#  'Institutional Logics and the Historical Contingency of Power in Organizations: Executive Succession in the Higher Education Publishing Industry, 1958– 1990',
#  "Objectivity as Strategic Ritual: An Examination of Newsmen's Notions of Objectivity",
#  'The Economics of Organization: The Transaction Cost Approach',
#  'Locally Ensconced and Globally Integrated: How Network Cohesion and Range\xa0Relate to a Language-Based Model of Organizational Identification',
#  'Higher Degrees in Sociology, 1954',
#  'The Structural Sources of Adventurism: The Case of the California Gold Rush',
#  'The Location of Change in the Sexual Structure of Occupations, 1950-1970: Insights from Labor Market Segmentation Theory',
#  'The Amount and Nature of Crime',
#  'Status Inconsistency and Ethnoreligious Group Membership as Determinants of Social Participation and Political Attitudes',
#  'Order and Conflict Theories of Social Problems as Competing Ideologies',
#  'The Church and the City Community',
#  'The Capitalization of Social Development',
#  '525‐527',
#  'Status and Leadership in a Combat Fighter Squadron',
#  'On Bolton\'s "Alienation and Action: A Study of Peace-Group Members"',
#  'The Natural History of Standard Metropolitan Areas',
#  'Conceptions of Organizational Worth',
#  'The Process of Urbanization and Criminal Behavior',
#  'Education',
#  'Sex Segregation, Labor Process Organization, and Gender Earnings Inequality',
#  'Urbanization and Fertility',
#  'Spatial Patterning of Urban Population Characteristics',
#  'Inventions and Discoveries',
#  'Race Relations',
#  'Bureaucrats and Entrepreneurs: Institutional Responses to Deviant Children in the United States, 1890-1920s',
#  'Some Contributions to the History of Sociology. Section IV. Niebuhr (1776-1831) and Scrutiny of Evidence: Early Roman History',
#  'Race Consciousness Among South African Natives',
#  'Cross-national Patterns and Determinants of Female Retirement',
#  'The Ecological Approach to the Church',
#  'The Rural Mind: A Study in Occupational Attitude',
#  'The Illinois Child-Labor Law',
#  'Science, Class, and the Welfare State: A Class-centered Functional Account',
#  'Making Love out of Nothing at All? Null Findings and the Trivers‐Willard Hypothesis',
#  'The Social Function of War Observations and Notes',
#  "An Alternative Model to Szymanski's",
#  'The Factorial Ecology of Calcutta',
#  'Progress as a Sociological Concept',
#  'Interviewing Homosexuals',
#  'Science and Sociology',
#  'Why the Poor Support Populism: The Politics of Sincerity in Metro Manila',
#  'The American Sociological Society',
#  'Disagreement over the Evaluation of a Controlled Experiment',
#  'The Socially Inadequate: How Shall We Designate and Sort Them?',
#  'The Role of the Intellectual in the Modern World',
#  'Controversies in Doctrine and Method',
#  'Sociology and Psycho-Analytic Psychology: An Interpretation of the Freudian Hypothesis',
#  'A Three-Generational Approach to Trends in Occupational Mobility',
#  "The World's First Sociological Laboratory",
#  'Stimulating (In)equality? The Earnings Penalty in Different-Sex and Female Same-Sex Couples Transitioning to Parenthood in Denmark, Finland, Norway, and Sweden',
#  'Demography in Relation to Sociology',
#  'What is Americanism? Supplement',
#  'The Effects of Slum Clearance and Rehousing on Family and Community Relationships in Minneapolis',
#  'The Legalization of the Workplace',
#  'A Durkheim Revival',
#  'The Social Waste of Unguided Personal Ability',
#  'Rise of the German Inner Mission. I',
#  'Moving beyond Stylized Economic Network Models: The Hybrid World of the Indian Firm Ownership Network',
#  'The Personality of Edward Alsworth Ross',
#  'Historical Ideals and the Great War',
#  'The Genesis of Ethical Elements',
#  'Dissonance-Congruence and the Perception of Public Opinion',
#  'Individual and Group Behavior',
#  'Individual, Group, and Social Field',
#  'Socialization',
#  'The Peopling of the Prairie Provinces of Canada',
#  'Sociology and Theism',
#  'Plans for the History of World War II',
#  'Methodological Convergence of Mead, Lundberg, and Parsons',
#  "Doctor's Degrees in Sociology, 1961",
#  'Four Synthesists: Cross-Sections From Comte, Spencer, Lilienfeld, and Schaeffle',
#  'Vagrancy and Begging',
#  'Race Making in a Penal Institution',
#  'The Eta: A Marginal Japanese Caste',
#  'The City in History',
#  'Some Influence of Hebraic Culture on Modern Social Organization',
#  'The Social Philosophy of the Old South',
#  'Nationality Origin and Religious Background an Approach to the Study of Religious Institutions',
#  'The Social Conscience and the Family',
#  'The Literary Interests of Chicago. V',
#  'Characteristics of the Non-Naturalized',
#  'Development Towns in Israel: The Role of Community in Creating Ethnic Disparities in Labor Force Characteristics',
#  'Infant Welfare: Methods of Organization and Administration',
#  'Courtship in College Women',
#  'The Changing Sex Ratio in the United States',
#  'The Study of Homeric Religion',
#  'The Place of Social Science in Germany Today',
#  'Inventions and Discoveries',
#  'Social Adjustments in Cities',
#  'Profit-Sharing and Cooperation. I',
#  'The Embeddedness of Adolescent Friendship Nominations: The Formation of Social Capital in Emergent Network Structures',
#  'Introduction to Sociology. XIII',
#  'The Potential Rate of Increase of the Population of the United States',
#  'New Developments in Audience Research Methods',
#  'Some Contributions to the History of Sociology. Section XV. The Restoration of Ethics in Economic Theory. The Professorial Socialists. The Verein Fur Socialpolitik.',
#  'The Influence of Newspaper Presentations Upon the Growth of Crime and Other Anti-Social Activity',
#  'Czech Sociology',
#  'Cracks in Broken Windows: How Objects Shape Professional Evaluation',
#  'Mobility and Work Satisfaction: A Discussion of the Use and Interpretation of Mobility Models',
#  'Another Look at Residential Turnover in Urban Neighborhoods: A Note on "Racial Change in a Stable Community" by Harvey Molotch',
#  'Citizenship Rights for Immigrants: National Political Processes and Cross-National Convergence in Western Europe, 1980–2008',
#  'Runaway Train? The Diffusion of State‐Level Reform in ADC/AFDC Eligibility Requirements, 1950–1967',
#  'Corporate Governance and Nested Authority: Cohesive Network Structure, Actor-Driven Mechanisms, and the Balance of Power in American Corporations',
#  'The Negro: Is He a Biological Inferior?',
#  'Replacing Members with Managers? Mutualism among Membership and Nonmembership Advocacy Organizations in the United States',
#  'Opportunity and Choice in Socially Structured Labor Markets',
#  'Religion',
#  'Politics and Crime',
#  'The Course of Mother-Tongue Diversity in Nations',
#  'NASA Revisited: Theory, Analogy, and Public Sociology',
#  'The Sociology of Ferdinand Tonnies',
#  'Simmel, Durkheim, and Ratzenhofer',
#  'Patterns of Management and Adaptations to Organizational Roles: A Study of Prison Inmates',
#  'Cowbirds, Locals, and the Dynamic Endurance of Regionalism',
#  'Norms: The Problem of Definition and Classification',
#  'Theory, Deduction, and Rules of Correspondence',
#  'Authoritarianism as World View',
#  'Charisma, Recognition, and the Motivation of Scientists',
#  'Comment: Controversies and Evidence in the Market Transition Debate',
#  'The Preindustrial Family in America: A Further Examination of Early Magazines',
#  'A Quantitative Analysis of Intragroup Relationships',
#  'How Not to Measure Intergenerational Occupational Persistence',
#  'Contemporary Sociology',
#  'Fifty Years of Sociology in the United States (1865-1915)',
#  'Sociology and History; Theory and Practice',
#  'The Social Class Structure of Occupational Mobility',
#  'A Note on the Concept of Role Distance',
#  'Intersectional Complexity in Stereotype Content',
#  'Exposure to Child-Rearing Experts: A Structural Interpretation of Class-Color Differences',
#  'The Structure of American Cities in the Post-War Era',
#  'The Regional Balance of Man',
#  'The Teaching of Sociology in the United States',
#  'The Effects of U.S. Immigration on the Career Trajectories of Native Workers, 1979–2004',
#  'The Ethics of Wealth',
#  'The Politics of American Sociologists',
#  'Disavowing Politics: Civic Engagement in an Era of Political Skepticism',
#  'Features of Educational Attainment and Job Promotion Prospects',
#  'Physical Attractiveness, Opportunity, and Success in Everyday Exchange',
#  'The Subcultural Theory of Urbanism: A Twentieth-Year Assessment',
#  'Positive Effects of the Multiple Negative: Explaining the Success of Black Professional Women',
#  'Lifetime Inheritances of Three Generations of Whites and Blacks',
#  'Settler Colonial Power and the American Indian Sovereignty Movement: Forms of Domination, Strategies of Transformation',
#  'Occupational Prestige in Urban China',
#  'The Sociology of Gambling',
#  'A Preference‐Opportunity‐Choice Framework with Applications to Intergroup Friendship',
#  "Bending with the Wind: Strategic Change and Adaptation by Women's and Racial Minority Organizations",
#  "It's about Time and Gender: Spousal Employment and Health",
#  'Abortion Liberalization in World Society, 1960–2009',
#  'Command, Control, and Charisma: Reflections on Police Bureaucracy',
#  'Stepwise International Migration: A Multistage Migration Pattern for the Aspiring Migrant',
#  'Structuring a Theory of Moral Sentiments: Institutional and Organizational Coevolution in the Early Thrift Industry',
#  'A Note on Emotionality, Self, and Interaction',
#  'A Sociology of Discordance: Negotiating Schemas of Deservingness and Codified Law in U.S. Asylum Status Determinations',
#  'Work as Foraging: A Smartphone Study of Job Search and Employment after Prison',
#  'Skin Tone and Stratification in the Black Community',
#  'Status in Experimentally Produced Groups',
#  'To Explain Political Processes',
#  'Insiders and Outsiders: A Chapter in the Sociology of Knowledge',
#  'Panethnicity, Ethnic Diversity, and Residential Segregation',
#  'Edgework: A Social Psychological Analysis of Voluntary Risk Taking',
#  'Characteristics of Military Society',
#  'Rearranging the Desk Chairs: A Large Randomized Field Experiment on the Effects of Close Contact on Interethnic Relations',
#  'The Population Ecology of Organizations',
#  'Professions in Process',
#  'Symbolic Representation and the Urban Milieu',
#  'Self-Perceptions of Black Americans: Self-Esteem and Personal Efficacy',
#  'Community Structure and Crime: Testing Social-Disorganization Theory',
#  'Legal Environments and Organizational Governance: The Expansion of Due Process in the American Workplace',
#  'Path Analysis: Testimonial of a Proselyte',
#  'Are Rural Services Obsolescent?',
#  'Political Judgments and the Perception of Social Relationships: An Analysis of Some Applied Social Research in Late 19th-Century Germany',
#  "Law in Pareto's Sociology",
#  'Rural Criminal Offenders',
#  'Explaining the Persistence of Health Disparities: Social Stratification and the Efficiency-Equity Trade-off in the Kidney Transplantation System',
#  'Structural Change and the Durkheimian Legacy: A Macrosocial Analysis of Suicide Rates',
#  'The Dynamics of Collapse in an Authoritarian Regime: China in 1967',
#  'A Typology of Rank-And-File Union Members',
#  "Their Brothers' Keepers? Orthodox Religionists, Modernists, and Economic Justice in Europe",
#  'Indices of Civilization',
#  'Economic Deprivation and Extremism: A Study of Unemployed Negroes',
#  'Contributions to the Comparative Study of Association',
#  'Knowledge, Meaning, and Social Inequality in Kenneth Burke',
#  'Group Behavior in the Village Community of Lebanon',
#  'French-Canadian Patriotism',
#  'What Shall We Do With the State? I',
#  'Lester Frank Ward',
#  'A Research Note on the Influence of Immigration on the Birth Rate',
#  'The Law Relating to the Relief and Care of Dependents. IV. Dependent Children',
#  'Introduction to Sociology. VII',
#  'Population Areas and Physiographic Regions in Canada',
#  'The Law of the Organism: A Neuro-Social Approach to the Problems of Human Behavior',
#  'Social Psychology Studies Adjustment Behavior',
#  'Some Contributions to the History of Sociology. Section VIII. Approaches to Objective Economic and Political Science in Germany: Cameralism',
#  'Selected References on Social Psychiatry',
#  'Resolving the Condorcet Paradox',
#  'Albion Woodbury Small, 1854-1926',
#  'German Fertility Trends, 1933-39',
#  'The Opium Trade in the Dutch East Indies. II',
#  'Alfred Weber-The Sociologist as a Humanist',
#  'Corporate Taxation and Corporate Economic Power: Testing Class-Power and Business-Confidence Models',
#  'On Linking Cultural and Structural Models of Ethnicity: A Synthesis of Schooler and Yancey, Ericksen, and Juliani',
#  'The Catholic Social-Reform Movement',
#  'Rats and Men',
#  'Community Organization',
#  "Critical Points in Ward's Pure Sociology",
#  "The Soldier's Language",
#  'Productivity, Favor, and Grants Among Scholars',
#  'A Note on Negro Alienation',
#  'Textbooks, Teachers, and Students',
#  'Some Economic Losses in the Building Trades',
#  'Was There a Prehistoric Trend from Smaller to Larger Political Units?',
#  'Psychological and Environmental Study of Women Criminals. II',
#  '"Visible" and "Invisible" Aspects of Personality',
#  'Inequality among Equals: Embedding Market and Authority in League Sports',
#  'Economic Dominants and Community Power a Comparative Analysis',
#  'Pressures and Defenses in Bureaucratic Roles',
#  'The Professional Self-Concept of Music Students',
#  'The Scope of Sociology. VI. Some Incidents of Association',
#  'Contributions to Social Philosophy. V. Sociology and Psychology',
#  'International Peace-By Court or Government?',
#  'From Weber to Parsons and Schutz: The Eclipse of History in Modern Social Theory',
#  'Society and Culture in Indonesian Nationalism',
#  'Landsmaal-Riksmaal: The Feud Between the Dialects and the Official Language of Norway',
#  'Racial Attitudes and the Employment of Negroes',
#  'Recent Manifestations of Sectionalism',
#  'The Political Theory of Calhoun',
#  'Social Transformations in East Africa',
#  'Psychic Causes of Rural Migration',
#  'The Origin of Democracy',
#  'Testing Coleman’s Social-Norm Enforcement Mechanism: Evidence from Wikipedia',
#  "The European Witch Craze: Still a Sociologist's Perspective",
#  'The Cumulative Texture of Local Urban Culture',
#  'Between-Firm Inequality and Informal Social Relations',
#  'Sociological Theory and Social Control',
#  'Vocabulary and Argot of Delinquent Boys',
#  'Italians and Crime in Chicago: The Formative Years, 1890-1920',
#  'Motivation and Aspiration of Southern Negro College Youth',
#  'Group Frustrations in Connecticut',
#  'Causes of Revolution',
#  'The Quantitative Study of Social Dynamics and Social Change',
#  'Farm Background and Urban Participation',
#  'Race Relations and Antidiscriminatory Legislation',
#  "The Delusions of Durkheim's Sociological Objectivism",
#  'Toward a Historical Sociology of Social Situations',
#  'Social Control. IV. Suggestion',
#  'Proximity and Peership: Bases of Balance in Interpersonal Attraction',
#  'The Reliability and Validity of Interview Data Obtained from 59 Narcotic Drug Addicts',
#  'Race and Sex Variations in the Causes of the Expected Attainments of High School Seniors',
#  'Sources of the Family Income Differentials among Hispanics, Blacks, and White Non-Hispanics',
#  'Dynamic Analysis of Event Histories',
#  'Payment Systems and the Structure of Inequality: Conceptual Issues and an Analysis of Salespersons in Department Stores',
#  'Sons, Daughters, and the Risk of Marital Disruption',
#  'Implications of a Standard of Living',
#  "Descent and Polity: The Meaning of Paige's Findings",
#  'Radio and National Morale',
#  'The Operational Approach is as New as Nonteleological Definitions',
#  'The "Social Concept" Bugbear',
#  'The Need of a Sociological Approach to Problems of Sex Conduct. I. Radical Practices Cannot Be Justified by Merely Biological Data',
#  'Some Contributions to the History of Sociology. Section XII. The Attempts (About 1870) to Reconstruct Economic Theory by Appeal to Psychology',
#  'The Concept "Social Forces" in American Sociology. Section III. Geographic Factors as Social Forces',
#  'Trends of Change in Textbooks on the Family',
#  'The Plight of the Rich Man in a Democracy',
#  'Ethnic Family Patterns: The Italian Family in the United States',
#  'Protestantism in the Present World-Situation',
#  'Western European Mobility',
#  'Friendship, A Social Category',
#  'Sociology Applied in the Field of Health',
#  'How Chicago Met the Unemployment Problem of 1915',
#  'Some Practical Applications of Psychology in Government',
#  'The Chicago "Black Belt" as a Political Battleground',
#  'Carceral Passages: Coming of Age in Prison America',
#  'Analysis and Typology of Personality Misinterpretations',
#  'The Status of the Marine Radioman a British Contribution',
#  'Situational Sociology',
#  'Superiority and Subordination as Subject-Matter of Sociology. II',
#  'Variability in the Criminal Behavior of American Indians',
#  'Talcott Parsons, the Problem of Order in Society, and the Program of an Analytical Sociology',
#  'Sociology in Italy. The Sociological Tendency of Today',
#  'Analytical Models in the Study of Social Systems',
#  "The Children's Bureau",
#  'Ambivalent Cartesians: Durkheim, Montesquieu, and Method',
#  'Multiple Indicators and the Causal Approach to Measurement Error',
#  'On the Statistical Analysis of Mobility Tables',
#  "Does Foreign Capital Harm Poor Nations? New Estimates Based on Dixon and Boswell's Measures of Capital Penetration",
#  'The Neighborhood: A Study of Local Life in the City of Columbus, Ohio. I.',
#  'The Impact of War on American Institutions',
#  'Prison Laboratories',
#  'Some Ecological Patterns of Community Disorganization in Honolulu',
#  'Ideals in Education',
#  'The Myth of the M-Form? Governance, Consent, and Organizational Change',
#  'Public Ownership Versus Public Control',
#  'The Relation Between Sociology and Other Sciences',
#  'Institutionalizing Collective Memories of Hate: Law and Law Enforcement in Germany and the United States',
#  "The United States Supreme Court and the Utah Eight-Hours' Law",
#  'What is a Social Problem?',
#  'The Diverging Paths of Black-White Segregation in Urban America, 1970–1990',
#  'Group Threat and Policy Change: The Spatial Dynamics of Prohibition Politics, 1890–1919',
#  'Ballot Manipulation and the “Menace of Negro Domination”: Racial Threat and Felon Disenfranchisement in the United States, 1850–2002',
#  'The Division between Mental and Manual Labor: Artisan Education in Science in Nineteenth-Century Britain',
#  'Caste and Choice: The Influence of Developmental Idealism on Marriage Behavior',
#  'Individual, Collective, and Systems Rationality in Work Groups: Dilemmas and Market-Type Solutions',
#  'Market Partitioning and the Geometry of the Resource Space',
#  'Leadership in the Small Group',
#  'Ordaining Women: The Diffusion of an Organizational Innovation',
#  'World-Economic Trends in the Distribution of Income, 1965-1992',
#  'Redistribution and the New Fiscal Sociology: Race and the Progressivity of State and Local Taxes',
#  'The Social Gradations of Capital',
#  'Mental Disorders in Cities',
#  'The Contribution of Psychiatry to an Understanding of Behavior in Society',
#  'School Desegregation, Interracial Exposure, and Antibusing Activity in Contemporary Urban America',
#  'The Nature and Use of Biograms',
#  'The Spatial Scale and Spatial Configuration of Residential Settlement: Measuring Segregation in the Postbellum South',
#  'Crime and State Surveillance in Nineteenth-Century France',
#  'Is It True What They Say About Daddy?',
#  'Aggressive and Erotic Tendencies in Army Life',
#  'Social Structure, Institutions, and the Legal Status of Children in the United States',
#  'The Great Refusal: The West, the Rest, and the New Regulations on Homosexuality, 1970–2015',
#  'Ethnic and Racial Segregation in the New York Metropolis, 1960',
#  'On Changing Matchmaking, Marriage, and Fertility in Israel: Some Findings, Problems, and Hypotheses',
#  'Inheriting the Homeland? Intergenerational Transmission of Cross-Border Ties in Migrant Families',
#  'Social Integration and the Status-Attainment Process',
#  'Social Science and the Quest for a Just Society',
#  'Status, Autonomy, and Training in Occupational Mobility',
#  'Do Anti-Immigrant Laws Shape Public Sentiment? A Study of Arizona’s SB 1070 Using Twitter Data',
#  'Relative Deprivation and Internal Migration in the United States: A Comparison of Black and White Men',
#  'Rediscovering the 1%: Knowledge Infrastructures and the Stylized Facts of Inequality',
#  'Religion, Disability, Depression, and the Timing of Death',
#  'A Critique of Criminology: Toward an Integrated Structural-Marxist Theory of Delinquency Production',
#  "Legal Custody Arrangements and Children's Economic Welfare",
#  'Emergence in Sociology: Contemporary Philosophy of Mind and Some Implications for Sociological Theory',
#  'An Economic Approach to Influence Activities in Organizations',
#  'The Sociology of Sociability',
#  'Network Connections and the Distribution of Power in Exchange Networks',
#  'Investigating the Temporal Dynamics of Interorganizational Exchange: Patient Transfers among Italian Hospitals',
#  'Interlock Globally, Act Domestically: Corporate Political Unity in the 21st Century',
#  'Autonomy in a Social Topology',
#  'Social Class and Income Inequality in the United States: Ownership, Authority, and Personal Income Distribution from 1980 to 2010',
#  'Counting Clicks: Quantification and Variation in Web Journalism in the United States and France',
#  'The Informant in Quantitative Research',
#  'Structural Position in the World System and Economic Growth, 1955-1970: A Multiple-Network Analysis of Transnational Interactions',
#  'Swift Neighbors and Persistent Strangers: A Cross‐Cultural Investigation of Trust and Reciprocity in Social Exchange',
#  'The Employee Society',
#  'The Increasing Growth-Rate of the Negro Population',
#  'Moot Points in Sociology. VII. The Factors of Social Change',
#  'A Note on the Term "Social Evolution"',
#  'Redirection of Education in Small Cities and Towns of Washington: Vocational Instruction the Entering Wedge of Redirection',
#  'The Religious Dedication of Women',
#  'War, Economic Motives, and Economic Symbols',
#  'The Transition to an Objective Standard of Social Control',
#  'Government',
#  'Organized Religion',
#  'The Psychology of Drink',
#  'The Criterion of Distributive Justice',
#  'Homophily and Segregation in Cooperative Networks',
#  'The Beginnings of Modern Demography',
#  'Employment, Unemployment, and Related Conditions of Labor',
#  'Race Relations',
#  'Legislation as a Social Function',
#  'Age, Housing Choice, and Neighborhood Age Structure',
#  'A Sociological View of Sovereignty. V',
#  'The Future of Social Mobility Studies',
#  'From Apron Strings to ABCs: Parents, Children, and Schooling in Nineteenth-Century Massachusetts',
#  '"Social Determination" in the Writings of Negro Scholars',
#  "Student's Dissertations in Sociology",
#  'How Education Is Faring',
#  'Individual and Person',
#  'The Selection of Problems for Research',
#  'Studies in the Sociology of Religion. IV. The Problems of Group-Consensus; Founding the Missouri Synod',
#  'Estimates of the Future Number of Families',
#  'Psychology in Social Relations',
#  'Foci of Discrimination in the Employment of Nonwhites',
#  'Rural Life',
#  'Social Control. XI',
#  'The Migration to Towns and Cities. II',
#  'Training a Socialized Rural Leadership',
#  'Competition',
#  'The Educational Process and the Brazilian Negro',
#  'Wealth and Its Ways',
#  'Ritual the Conserver',
#  'Factory Legislation for Women in Canada',
#  'Social Legislation',
#  'The Recent Campaign Against Labor Organizations in Germany',
#  'Uncle Sam Unwhiskered',
#  'Trends in the Size of Families Completed Prior to 1910 in Various Social Classes',
#  'Occupational wage Inequality and Devaluation: A Cautionary Tale of Measurement Error',
#  'Intermetropolitan Migration: A Correlation Analysis',
#  'Social Planning and Social Organization',
#  'Can Sociology and Social Psychology Dispense With Instincts?',
#  "Mate-Selection Among New York City's Chinese Males, 1931-38",
#  'Wyoming and the Westward Movement: Natal Statistics at the University of Wyoming',
#  'The Court and the Delinquent Child',
#  'Morale and Minority Groups',
#  'Postcolonial Reckonings and Arrival',
#  'Multiple Discoveries and the Central Message',
#  'The Significance of the Orient for the Occident',
#  'Psychiatry and Sociology in Relation to Social Disorganization',
#  'Biblical Sociology. IV',
#  'Biblical Sociology. I',
#  'Contemporary Sociology. III',
#  'Natural Resources',
#  'The Gypsy in a Non-Gypsy Economy',
#  'The Background of a State "Boss" System',
#  'Introduction to Sociology. XI',
#  'The Age Factor in Marriage: A Philadelphia Study, 1931',
#  'Cultural Participation and the Negro',
#  'The Background of the New Deal',
#  'The Influence of Income on Standards of Life',
#  'The Prussian-Polish Situation: An Experiment in Assimilation',
#  'The False Enforcement of Unpopular Norms',
#  'The Materiality of Ideology: Cultural Consumption and Political Thought after the American Revolution',
#  'The Evaluation of Occupations by Warsaw Inhabitants',
#  'Racial Differences in Household and Family Structure at the Turn of the Century',
#  'Unification Research Programs: Integrating Two Structural Theories',
#  'Class and Family in a Modernizing Society',
#  'Exchange, Structure, and Symmetry in Occupational Mobility',
#  'Ethnic Stratification and Political Cleavage in the United States, 1952-68',
#  'Illegitimacy and the Social Structure',
#  'Factors Which Have to Do with the Decline of the Country Church',
#  'The Urban Habit of Mind',
#  'Some Social Functions of Religion in Rural Japan',
#  'Citizenship, Education, and Culture',
#  'Resistance to Innovation: The Case of Atomic Power',
#  'The Disciplining Effect of Mass Incarceration on Labor Organization',
#  'Reflections of Social Disorganization in the Behavior of a Schizophrenic Patient',
#  'Critical Theory: Is There Still Hope?',
#  'The Neighborhood: A Study of Local Life in the City of Columbus, Ohio. II.',
#  'Local Marriage Markets and the Marital Behavior of Black and White Women',
#  'Social Psychological Variables and Their Relevance to the Status Attainment of Teenagers',
#  'Adjustment to Military Life',
#  'Regional and Racial Effects on the Urban Homicide Rate: The Subculture of Violence Revisited',
#  'Social and Biological Struggles',
#  'The Sutherland-Glueck Debate: On the Sociology of Criminological Knowledge',
#  'Prolegomena to Social Psychology. IV. The Concept of the Social Mind',
#  'The Academic Marketplace Revisited: A Study of Faculty Mobility Using the Cartter Ratings',
#  'White Pressures on Indian Personality and Culture',
#  'Mayoral Influence in Urban Policy Making',
#  'Constructing Polities and Markets: An Institutionalist Account of European Integration',
#  'The Scope of Sociology. VII. Classification of Associations',
#  'Contrasting Institutions of Air Force Socialization: Happenstance or Bellwether?',
#  'Negro Racial Movements and Leadership in the United States',
#  'The Structure of Sibling Relationships',
#  'The Determination of Local Power Elites',
#  '“Taking the State at Its Word”: The Arts of Consentful Contention in the German Democratic Republic',
#  'Toward a Revised Model of Residential Segregation and Succession: Puerto Ricans in New York, 1960-1970',
#  'Intermarriages Between German Pioneers and Other Nationalities in Minnesota in 1860 and 1870',
#  'The Meaning and End of Religiosity',
#  'The Klan Revival',
#  "A Study of Pareto's Treatise on General Sociology",
#  'Early Adolescent Self-Esteem as a Function of Social Class: Rosenberg and Pearlin Revisited',
#  'Mesolevel Networks and the Diffusion of Social Movements: The Case of the Swedish Social Democratic Party',
#  'Electoral Participation and the Occupational Composition of Cabinets and Parliaments',
#  'Getting Personal: Networks and Stratification in the Russian Labor Market, 1985–2001',
#  'Neglected Widowhood in the Juvenile Court',
#  'Moot Points in Sociology. VIII. The Factors of Social Change',
#  'The Study of the Delinquent as a Person',
#  'Technology, Biology, and the Changing Family',
#  'Trade Cohesion, Class Unity, and Urban Insurrection: Artisanal Activism in the Paris Commune',
#  'The Persistence of Status Advantages in Soviet Russia',
#  'A Simulation of the SIVA Model of Organizational Behavior',
#  'Indicators of Sex Typing: Traditional and Egalitarian, Situational and Ideological Responses',
#  'The Relation of Social Theory to Public Policy',
#  'Undergraduate Aspirations: A Test of Several Theories',
#  'The Establishment of Sociology',
#  'A Note on Governmental Research on Attitudes and Morale',
#  'Labor-Market Experiences and Labor-Force Outcomes',
#  'Money and Finance',
#  'Industrial Conflict and Its Mediation',
#  'Community Leadership: A Case Study and Conceptual Refinement',
#  'Some Economic Effects of Revolution: Models, Measurement, and the Cuban Evidence',
#  'The Culture Area Concept as a Research Lead',
#  'Industrialization and the Stratification of Cities in Suburban Regions',
#  'Prejudice, Discrimination, and the Labor Market: Attainments of Immigrants in Australia',
#  'A Review of Sex Role Research',
#  'Multidimensional Scale Analysis',
#  'Occupational Status-Assignment Systems: The Effect of Status on Self Esteem',
#  'The Organizational Context of Criminal Sentencing',
#  'Race and the Local Politics of Punishment in the New World of Welfare',
#  'The Optimum Size of Institutions a Theory of the Large Group',
#  'The Great Interstate Divergence: Partisan Bureaucracies in the Contemporary United States',
#  'Getting Ahead in Urban China',
#  'Intraracial Diversity and Relations among African‐Americans: Closeness among Black Students at a Predominantly White University',
#  'Neighborhood Effect Heterogeneity by Family Income and Developmental Period',
#  'The Structure of Educational Decision Making and Consequences for Inequality: A Swedish Test Case',
#  'Pensioner Employment, Well-Being, and Gender: Lessons from Russia',
#  'Who Will Gain and Who Will Lose Influence Under Different Electoral Rules',
#  'Racial Context and Police Force Size: Evaluating the Empirical Validity of the Minority Threat Perspective',
#  'Social Organization, Collective Sentiment, and Legal Sanctions in Murder Cases',
#  'Distress and the Traditional Female Role: A Comparison of Mexicans and Anglos',
#  'Imprisonment and Labor Market Outcomes: Evidence from a Natural Experiment',
#  'A Social-Psychological Theory of the Authoritarian Personality',
#  'Occupational Prestige in the United States, 1925-63',
#  'From Reflection to Refraction: State Administration in British India, circa 1770–1855',
#  'Taking a Pass: How Proportional Prejudice and Decisions Not to Hire Reproduce Gender Segregation',
#  'Wealth and the Marital Divide',
#  'Community (Dis)Organization and Racially Motivated Crime',
#  'Making it Underground: Comparative Material on the Informal Sector in Western Market Economies',
#  'Disaster, Organizing, and Role Enactment: A Structural Approach',
#  'Fame and Misfortune: Edging Women Out of the Great Literary Tradition',
#  'The Race Is to the Swift: Socioeconomic Origins, Adult Education, and Wage Attainment',
#  'The Making and Unmaking of Ethnic Boundaries: A Multilevel Process Theory',
#  'Educational Mobility among the Children of Asian American Immigrants',
#  'The Persistence of Extreme Gender Segregation in the Twenty-first Century',
#  'Face and Favor: The Chinese Power Game',
#  'Opportunity Organizations and Threat‐Induced Contention: Protest Waves in Authoritarian Settings',
#  'Community and Individual Ethnicity: The Structural Context of Economic Performance',
#  'The Frequency and Probability of Insanity',
#  'The Problem of Civilization in the Twentieth Century',
#  'Chicago Housing Conditions, IX: The Lithuanians in the Fourth Ward',
#  'The Origin of Society',
#  'American Sociology in Japan',
#  'A Skeptical Note on the Relation of Vertical Mobility to Education',
#  'A Vision of Social Efficiency',
#  'Introduction to Sociology. III',
#  'Christian Sociology. VIII. The Process of Social Regeneration.',
#  'National Differences in Creativity',
#  'Education',
#  'The Human Element in Production',
#  'The Sentiment of White Supremacy an Ecological Study',
#  'Higher Degrees in Sociology Conferred in 1938',
#  "Industrial Insurance. I. The Extent and Nature of the Demand for a Social Policy of Workingmen's Insurance",
#  'Ethnic Inequality in Israeli Schools and Sports: An Expectation-States Approach',
#  'Prolegomena to Social Psychology. III. The Nature and Task of Social Psychology',
#  'Some Social Aspects of the Chicago Stock Yards. Chapter II. The Stock Yard Community at Chicago',
#  'Some Sources of American Hostility to Russia',
#  'Patients and Prejudice: Lay Attitudes Toward Women Physicians',
#  'Social Control. VII. Assemblage',
#  'The Ford Motor Company Incident',
#  'For Sociology: "Varieties of Political Expression" Revisited',
#  'The Periodical Literature of Sociology',
#  'A Plea and Plan for a Cooperative Church Parish System in Cities',
#  'Sectarianism and Religious Sociation',
#  'The Movement for Small Playgrounds',
#  'Bureaucratic Initiative in Capitalist New Zealand: A Case Study of the Accident Compensation Act of 1972',
#  'One Hundred Years of Marriages in Massachusetts',
#  'A Sociological View of Sovereignty. III',
#  'The Measurement of Marital Strain',
#  'The Barrier of Legalism',
#  'Economic and Political Radicalism',
#  'Social Assimilation. II',
#  'Occupational Mobility and Urban Social Life',
#  'Internal Migrations in Sweden: A Note on Their Extensiveness as Compared with Net Migration Gain or Loss',
#  'An Analysis of the Population of the Texas Penitentiary from 1906 to 1924',
#  'Social Decadence',
#  'Agricultural Education and Its Relation to Rural Sociology',
#  'Insanity a Social Problem',
#  'Age Distribution as a Challenge to Development',
#  'Under the Influence of Genetics: How Transdisciplinarity Leads Us to Rethink Social Pathways to Illness',
#  'Cultural Contacts in an Isolated Community Tristan Da Cunha',
#  'Some Demands of Education Upon Anthropology',
#  'The Relation of Anthropology to the Study of History',
#  'The State, International Agencies, and Property Transformation in Postcommunist Hungary',
#  'Doctoral Dissertations in Sociology, 1951',
#  'Sociopsychological and Cultural Factors in Race Relations',
#  'An Evaluation of "Themes" and Kindred Concepts',
#  'The Sex Lives of Unmarried Men',
#  "Guttman Scaling Applied to Centers' Conservatism-Radicalism Battery",
#  'Religion and Social Institutions',
#  'Metropolitan Growth: An International Study',
#  'Volunteer Subjects as a Source of Sampling Bias',
#  'Current Population Trends in Latin America',
#  'Models of Relevance: The Social Effects of Sociology',
#  'The Social Elements of the Indian Problem',
#  'The Study of Sociology in Institutions of Learning in the United States. IV',
#  'The Retail Furrier: Concepts of Security and Success',
#  'Age Stratification and the Changing Family',
#  "Reiss Comments on Selbyg's Review of Zetterberg",
#  'Rural Life',
#  'Psychiatry and Suicide: The Management of a Mistake',
#  'Migration',
#  'Qualitative Selection in Cityward Migration',
#  'On "Validity" As a Criterion',
#  'Education, Occupation, and Wage Differences Between White and Black Men',
#  '"American Lawlessness": An Inquiry',
#  'Sociological Construction Lines. I',
#  'Boundary Lines of Social Phenomena',
#  'The Concept of Neighborliness',
#  'Optimism and Pessimism in College Environments',
#  'Segregation in Southern Cities',
#  'The Structure of Authority in Non-Industrial Production Organizations',
#  'Sociology and the Psychoanalytic Method',
#  'Robert Dale Owen, The Pioneer of American Neo-Malthusianism',
#  'Sons, Daughters, and Intergenerational Support in Taiwan',
#  'Learning to Cooperate: Stochastic and Tacit Collusion in Social Exchange',
#  'Impressions of Sociology in Great Britain',
#  'Efficiency and "The Fix": Informal Intergroup Relations in a Piecework Machine Shop',
#  'She Works Hard for the Money: Household Responsibilities and the Allocation of Work Effort',
#  'The Instability of Androgynous Names: The Symbolic Maintenance of Gender Boundaries',
#  'Does Educational Equality Increase Mobility? Exploiting Nineteenth-Century U.S. Compulsory Schooling Laws',
#  'Opinion Polarization: Important Contributions, Necessary                         Limitations',
#  'Racial Change in a Stable Community',
#  'The Chicago Employment Agency and the Immigrant Worker',
#  'Residential Distribution and Stratification, 1950-1960',
#  'Social Selection and Stratification Within Schools',
#  'Observations on the Study of Crime Causation',
#  'Why No Trade‐off between “Guns and Butter”? Armed Forces and Social Spending in the Advanced Industrial Democracies, 1960–1993',
#  'Is the Rate of Invention Declining?',
#  'Maid of All Work or Departmental Sister-in-Law? The Faculty Wife Employed on Campus',
#  'Ethnic and Minority Groups in Wartime, with Special Reference to the Negro',
#  'Prediction in Macrosociology: The Case of the Soviet Collapse',
#  'The Sociology of Conflict. III',
#  'Difficulties of Statistical Interpretation of Case Records of Delinquency and Crime',
#  'The Expert in the Labor Movement',
#  'The Spatial Distribution of Divorced Women-A Philadelphia Study',
#  'The Folk Society',
#  'Position in the Class Structure and Psychological Functioning in the United States, Japan, and Poland',
#  'Human Nature and Collective Behavior',
#  'Legal Evolution and Societal Complexity',
#  'Appearance and Criminality',
#  'Slavery’s Carceral Legacy in the Jim Crow South',
#  'Sociology and the Social Sciences: The Social Organism and the Collective Mind',
#  'Interviewing Frenchmen',
#  "On Camic's Antipresentist Methodology",
#  'Blocked Acculturation: Cultural Heterodoxy among Europe’s Immigrants',
#  'Operational Definitions in the Social Sciences',
#  'Economic Self-Reliance and Gender Inequality between U.S. Men and Women, 1970–2010',
#  'Status Discrepancy and Prejudice',
#  'A Research Note: A Social Structural Model for the Socioeconomic Career',
#  'Religion as Opposition: A Gramscian Analysis',
#  'Continuity in City-Manager Careers',
#  'Interethnic Friendship, Trust, and Tolerance: Findings from Two North Iraqi Cities',
#  '(Not) Feeling the Past: Boredom as a Racialized Emotion',
#  'Greed and Contingency: State Fiscal Crises and Imperial Failure in Early Modern Europe',
#  'Becoming Full Citizens: The U.S. Women’s Jury Rights Campaigns, the Pace of Reform, and Strategic Adaptation',
#  'Spanning the Institutional Abyss: The Intergovernmental Network and the Governance of Foreign Direct Investment',
#  'Parents, Partners, and Professions: Reproduction and Mobility in a Cohort of College Women',
#  'Self-Correcting Dynamics in Social Influence Processes',
#  'Arts and Crafts',
#  'Jim Crow, Ethnic Enclaves, and Status Attainment: Occupational Mobility among U.S. Blacks, 1880–1940',
#  'Craps and Magic',
#  'State Building and Religion: Explaining the Diverged Path of Religious Change in Taiwan and South Korea, 1950–1980',
#  'The Positive Functions of Poverty',
#  'The Instinct of Workmanship and the Irksomeness of Labor',
#  'Critical Theory and the Pragmatist Challenge',
#  'War and Peace: The Evolution of Modern Personnel Administration in U.S. Industry',
#  'Intergenerational Consequences of Family Disruption',
#  'The Concept of Bureaucracy: An Empirical Assessment',
#  'Terrorist Events and Attitudes toward Immigrants: A Natural Experiment',
#  'Feral Children and Autistic Children',
#  'Class Forces, Political Institutions, and State Intervention: Subnational Economic Development Policy in the United States, 1971–1990',
#  'Population',
#  'The Social Construction of Anomie: A Four-Nation Study of Industrial Workers',
#  "Family Integration and Children's Self‐Esteem",
#  'Legal Ambiguity and Symbolic Structures: Organizational Mediation of Civil Rights Law',
#  'Making Use of the Past: Time Periods as Cases to Compare and as Sequences of Problem Solving',
#  'The Power Elite-Reconsidered',
#  'Corporate Ownership and Control: The Large Corporation and the Capitalist Class',
#  'Effectively Maintained Inequality: Education Transitions, Track Mobility, and Social Background Effects',
#  "Cooley's Doctrine of Primary Groups",
#  'Is Social Capital Declining in the United States? A Multiple Indicator Assessment',
#  'The Charities Chapter of the Greater New York Charter',
#  'Government',
#  'The Passing of the Saint',
#  'Commentary and Debate, Rawls, Durkheim, and Causality: A Critical Discussion',
#  'Education',
#  'George Frederick Holmes and the Genesis of American Sociology',
#  'Social Tensions Between Farmer and Farm Laborer in Northern Holland',
#  'Planned Social Solidarity in the Soviet Union',
#  'The Clubs in Crisis: Race Relations in the New West Africa',
#  'Economic Foundations of the German Totalitarian State',
#  'Welfare Agencies, Special Education, and the Courts',
#  'Comments on Rushing\'s "Class, Culture, and \'Social Structure and Anomie\'"',
#  'Southern Birth and Racial Residential Segregation: The Case of Northern Cities',
#  'Inspirational Religious Literature: From Latent to Manifest Functions of Religion',
#  'Gorge City',
#  'Social Class and Sociability in Fraternity Pledging',
#  'A College Program for Rural Sociology',
#  'Immigration and Crime',
#  'The Status of Women',
#  'Intermarriage of Puerto Ricans in New York City',
#  'Antipathy and Social Behavior',
#  'Twenty Years of Sociology by Correspondence',
#  'Natural Resources in the Post-War World',
#  'Racial and National Intermarriage in a Brazilian City',
#  'Black Invisibility, the Press, and the Los Angeles Riot',
#  'The Place and Functions of Voluntary Associations',
#  'The Mind of the Citizen',
#  'Housing in Vienna: A Socialistic Experiment',
#  'The Voodoo Cult Among Negro Migrants in Detroit',
#  'Justice and Revolutionary Coalitions: A Test of Two Theories',
#  'Socioeconomic Status and Delinquent Behavior',
#  'The Locus of Racial Disadvantage in the Labor Market',
#  'Market and Nonmarket Pathways to Home Ownership and Social Stratification in Hybrid Housing Regimes: Evidence from Four Post-Soviet Countries',
#  'Economic Segmentation and Politics',
#  'The Neighborhood: A Study of Local Life in the City of Columbus, Ohio',
#  'The Paradox of Self-Help Expertise: How Unemployed Workers Become Professional Career Coaches',
#  'History, Sociology, and Contemporary Area Studies',
#  "Mayhew and Levinger's Use of Random Models",
#  'Marriage Among the Independent Lolos of Western China',
#  'Social Facts and Rules of Practice',
#  'Psychological and Environmental Study of Women Criminals. I',
#  'The People of Frilot Cove: A Study of Racial Hybrids',
#  'Why the Large Rise in the German Birth-Rate?',
#  'Isolation and Social Conflicts',
#  'The Social Thought of Jean-Paul Sartre',
#  'Approaches to the Study of Rural Government',
#  'Sociological Instruction at Paris',
#  'Sociology and the State',
#  'The Generalizations of Economic History',
#  'The Extra-Professional Role of the Lawyer',
#  'Neither Marx nor Durkheim . . . Perhaps Weber',
#  'Some Characteristics of Adoptive Parents',
#  'The Accuracy, Efficiency, and Validity of a Prediction Instrument',
#  'Factory Inspection in the United States',
#  'Inequality and the Relative Size of Minority Populations: A Comparative Analysis',
#  'Detecting Sentencing Disparity: Some Problems and Evidence',
#  'Dynamics of Professional Control: Internal Coalitions and Crossprofessional Boundaries',
#  'Residential Distribution and Occupational Stratification',
#  'Women and Work: The Psychological Effects of Occupational Conditions',
#  'Professionalization and Bureaucratization in Large Professional Organizations',
#  'Corporate Size, Bureaucratization, and Managerial Succession',
#  'Ethnic Behavior in Industry: Sponsorship and Rejection in a New England Factory',
#  'Occupational Differences in the Value Attached to Work',
#  'Recent Increases in Marriage and Divorce',
#  'Training for Rural Service',
#  'Studies in Political Areas. The Political Territory in Relation to Earth and Continent',
#  'Criminal Anthropology in Its Relation to Criminal Jurisprudence',
#  'Psychiatry in Medicine: Intra- Or Inter- Professional Relationships?',
#  'Changes in Population Distribution Since 1940',
#  "Patients' Socioeconomic Characteristics and Release from a Mental Hospital",
#  'The Hierarchy of European Races',
#  'Causal Models, Unobserved Variables, and Experimental Data',
#  'The Promotion Paradox: Organizational Mortality and Employee Promotion Chances in Silicon Valley Law Firms, 1946–1996',
#  'The Uneven Neoliberalization of Good Works: Islamic Charitable Fields and Their Impact on Diffusion',
#  'The Life Histories of W. I. Thomas and Robert E. Park',
#  'Suicidal Motor Vehicle Fatalities in Detroit: A Replication',
#  'A Contribution to the Study of Actuarial and Individual Methods of Prediction',
#  'Types of Nationalism',
#  'Schools for Dependent, Delinquent, and Truant Children in Illinois',
#  'Minimum-Wage Boards',
#  'Racial Differences in Underemployment in American Cities',
#  'Patterns of Residence in Poona (India) by Income, Education, and Occupation (1937-65)',
#  'Informal Relations in the Practice of Criminal Law',
#  'A Criminological Approach to the Social Control of International Aggressions',
#  'The Meaning of Sociology',
#  'Minority-Group Status and Fertility: An Extension of Goldscheider and Uhlenberg',
#  'Correlates of Success in Retail Selling',
#  'Sociology and Psychology; Sociology and Geography',
#  'Negro Prestige Criteria: A Case Study in the Bases of Prestige',
#  'Institutional Setting and Industrial Conflict in Quebec',
#  'The Influence of Sigmund Freud Upon Sociology in the United States',
#  'Trade-Union Government, Its Nature and Its Problems a Bibliographical Review, 1945-55',
#  'Economic Differentials in the Probability of Insanity',
#  'Measuring Role Conflict',
#  'Kinship, Marriage, and the Family: An Operational Approach',
#  'Law and Social Change: Sumner Reconsidered',
#  'Functionalism and the Functional Theory of Stratification: An Empirical Assessment',
#  'Problematics in Stratum Consistency and Stratum Formation: An Australian Example',
#  'Birth Control and the Sex-Ratio at Birth',
#  "The Social Context of Women's Labor Force Participation: A Comparative Analysis",
#  'Urbanization as Socioenvironmental Succession: The Case of Hazardous Industrial Site Accumulation',
#  'The Structural Balance Theory of Sentiment Networks: Elaboration and Test',
#  'Differential Depression Effects on Families of Laborers, Farmers, and the Business Class: A Survey of an Iowa Town',
#  'Social Consensus on Norms of Justice: Should the Punishment Fit the Crime?',
#  'The Rural-Urban Continuum: Real but Relatively Unimportant',
#  'Some Aspects of the Name in Culture-History',
#  'A Programme for Social Study',
#  'The Contribution of Voluntary Organizations to Community Structure',
#  "Durkheim's Theories of Deviance and Suicide: A Feminist Reconsideration",
#  'A Funny Thing Happened on the Way to the Orifice: Women in Gynecology Textbooks',
#  'The Americanization Movement',
#  'Social Change, the Social Organization of Families, and Fertility Limitation',
#  'Coalition Game Research: A Reexamination',
#  'Prolegomena to Social Psychology. II. The Fundamental Fact in Social Psychology',
#  'Social Origins, Education, and Fraternal Mobility',
#  'The New Parochialism: The Implications of the Beltway Case for Arguments Concerning Informal Social Control',
#  'Variation in the Relationship between School Spending and Achievement: Progressive Spending Is Efficient',
#  'Cumulative Advantage Processes as Mechanisms of Inequality in Life Course Health',
#  'Four-Variable Causal Models and Partial Correlations',
#  'Conservative Protestants and Wealth: How Religion Perpetuates Asset Poverty',
#  'Social Status and Newspaper Readership',
#  'Economic and Psychological Historiography',
#  'Moral Instruction Through Social Intelligence',
#  "A Test of Lindesmith's Theory of Addiction: The Frequency of Euphoria Among Long-Term Addicts",
#  'Cultural Orientations, Institutional Entrepreneurs, and Social Change: Comparative Analysis of Traditional Civilizations',
#  'Neglected Characteristics of Collective Behavior',
#  "Max Weber's Elective Affinities: Sociology Within the Bounds of Pure Reason",
#  'Ecologies of Social Movements: Student Mobilization during the 1989 Prodemocracy Movement in Beijing',
#  'Democracy versus Distinction: A Study of Omnivorousness in Gourmet Food Writing',
#  'Social Distance Between Client and Professional',
#  'Off‐Scheduling within Dual‐Earner Couples: An Unequal and Negative Externality for Family Time',
#  'Rumor and Public Opinion',
#  'Adolescent Competence and the Shaping of the Life Course',
#  'How is Society Possible?',
#  'Mind, Self, Society, and Computer: Artificial Intelligence and the Sociology of Mind',
#  'The Present Outlook of Social Science',
#  "The Evolution of the Institution of Mothers' Pensions in the United States",
#  'Multiple Indicators in Survey Research',
#  'A General Framework for Building Dynamic Macro Social Indicator Models: Including an Analysis of Changes in Crime Rates and Police Expenditures',
#  'Matching: Finding a Partner for Life or Otherwise',
#  'Creating and Spreading Status Beliefs',
#  'Deterrence, Poverty, and Type of Homicide',
#  'Social Class and Parental Values',
#  'Children and Marital Disruption',
#  'Nominal, Ordinal, and Narrative Appraisal in Macrocausal Analysis',
#  'Hierarchy and Ecological Control in Federal Budgetary Decision Making',
#  'Social Network Dynamics and Biographical Disruption: The Case of “First-Timers” with Mental Illness',
#  'Optics of the State: The Politics of Making Poverty Visible in Brazil and Mexico',
#  'Organizing Penal-Welfare Hybridity: Trauma, Vulnerability, and State Recognition of Crime Victims',
#  'The Transformation of Morals in Markets: Death, Benefits, and the Exchange of Life Insurance Policies',
#  'High School Effects on College Intentions',
#  'Capitalist Development, the Labor Process, and the Law',
#  'When Organizations Rule: Judicial Deference to Institutionalized Employment Structures',
#  'Where Is the Modern Sociology of Conflict?',
#  'Status and Status Strain in the Professions',
#  'The Integrative Power of Civic Networks',
#  'Reducing Income Inequality in Educational Attainment: Experimental Evidence on the Impact of Financial Aid on College Completion',
#  'Segregation in Social Networks Based on Acquaintanceship and Trust',
#  'Trends in Antiblack Prejudice, 1972-1984: Region and Cohort Effects',
#  "Culture as Class Symbolization or Mass Reification? A Critique of Bourdieu's Distinction",
#  'Toward the Sociology of Esoteric Culture',
#  'Human Migration and the Marginal Man',
#  'Rethinking the Risks of Poverty: A Framework for Analyzing Prevalences and Penalties',
#  'Gender, Race, and Meritocracy in Organizational Careers',
#  'Specifying the Relationship Between Social Ties and Activism',
#  'Systematic Social Observation of Public Spaces: A New Look at Disorder in Urban Neighborhoods',
#  'Representing Human Rights Violations in Darfur: Global Justice, National Distinctions',
#  'City Administration in Germany',
#  'Municipal Annexations and the Growth of Metropolitan Suburbs, 1950-60',
#  'Marxisms as Utopias: Evolving Ideologies',
#  'The Functional Differentiation of Elites in the Kibbutz',
#  'Local-Cosmopolitan: Unidimensional or Multidimensional?',
#  'Educational Climates of High Schools: Their Effects and Sources',
#  'The Nondirective Method as a Technique for Social Research',
#  'School Segregation in Metropolitan Regions, 1970–2000: The Impacts of Policy Choices on Public Education',
#  'Sex, Schooling, and Occupational Status',
#  'A Sociological Theory of Psychopathy',
#  'Socioeconomic Differentials Among Religious Groups in the United States',
#  'Co-Ordination of Federal Statistical Programs',
#  'The Social Problem and the Present War',
#  "An Indian's Soliloquy",
#  'Ethics and Its History: The Dependence of Ethics on Natural Science, and the Important Difference Between Ethics as Personal Experience and Ethics as a Social Profession',
#  'The Ethical Bases of Democracy',
#  'Intergroup Attitudes and Social Ascent Among Negro Boys',
#  'The Institutional Foundation of a Scientific Social Psychology',
#  'Concerning Another Response',
#  'The Child',
#  'Larithmics: An Addition to Sociological Terminology',
#  'Functions of a Sociology Department in a State University',
#  'Progress and the Constructive Instincts',
#  "Supplementary List of Doctoral Dissertations in Progress, 1958, and Master's Degrees Conferred in 1958",
#  'Punishment to Fit the Crime',
#  'News of Social Research in England',
#  'An Application of Statistical Method',
#  'The Civic Problem from a Sociological Standpoint',
#  'Roger V. Gould, 1966–2002',
#  'Earnings',
#  'Instinctive and Cultural Factors in Group Conflicts',
#  ...]

# %%
with open('ajs_paper_dois.txt', 'w') as f:
    for doi in ajs_paper_dois:
        f.write(f"{doi}\n")
